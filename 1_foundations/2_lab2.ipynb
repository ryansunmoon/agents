# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You're an independent advisor to the mayor of a coastal city of 1.2 million people (median household income $35k) facing three concurrent, interacting challenges over the next 30 years: projected mean sea-level rise of roughly 0.5–1.5 m by 2100, a projected 25% decline in the city's primary manufacturing tax base over 10 years, and an expected inflow of ~100,000 climate migrants over the next 15 years. The mayor needs a realistic, politically viable, prioritized 10-year action plan that minimizes fatalities and economic disruption, protects the most vulnerable residents, maintains basic services, and preserves democratic legitimacy. For each year of the 10-year plan, provide: (a) the top three policy actions and the concise rationale for each; (b) ballpark estimated costs (low/central/high) and one or two plausible funding mechanisms; (c) expected primary benefits and the key risks or negative externalities; (d) two to three measurable success metrics with target values for that year; (e) the single most important new piece of data the city should collect that year and why; and (f) one feasible contingency action if the primary policy fails. In addition, provide: (g) three ethical trade-offs you faced in designing the plan and how you resolved or prioritized among them; (h) three specific early-warning indicators (with threshold values) that would cause you to change course within the 10 years, and the alternative action you would take for each indicator; (i) a quantified expression of your uncertainty for the overall plan by assigning probabilities to three scenarios (optimistic / central / pessimistic) and a brief justification for those probabilities; and (j) a concise list of key assumptions you made and the top three outside experts or analyses you would commission before implementation. For every numbered item above, state your confidence level (low/medium/high) and be explicit about what you do not know or where your estimates are weakest.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a realistic, evidence-based 10-year strategy designed for a city of 3 million to cut peak-hour private-vehicle traffic by about 40% while advancing equity and economic opportunity. It focuses on five core interventions, each with rough cost bands, expected impacts, timelines, phasing, and financing, plus measurable metrics, anticipated obstacles, and mitigation measures for unintended harms.
#
# Executive framing
# - Target: reduce peak-hour private-vehicle trips by ~40% citywide, with disproportionate benefits for lower-income and underserved residents (better access to jobs, lower exposure to pollution, more affordable mobility).
# - Core logic: price-based demand management to reduce car trips (congestion pricing), paired with high-quality transit expansion, smarter parking, smarter land use near transit (TOD), and a safer, connected active-mobility network. Revenue from pricing and value-creation around transit supports the investments; equity measures ensure affordable access for those who need it most.
# - Risks to manage: political resistance, legal constraints on pricing, potential displacement, regressive effects if pricing is not paired with subsidies, and implementation delays. Mitigations emphasize transparent revenue use, targeted rebates, robust stakeholder engagement, and strong anti-displacement policies.
#
# Top five interventions (with rationale, rough costs, expected impact, timeline, and financing)
#
# 1) Congestion pricing with revenue recycling for transit and active-m mobility
# - What it is: charge vehicles entering a high-demand core zone during peak periods; use revenue to fund transit upgrades, fare subsidies, and walking/ciking safety improvements; implement waivers/exemptions for essential workers, people with disabilities, and low-income residents in a transparent, capped way.
# - Why it matters: evidence from global cities shows core congestion pricing can reduce peak car trips in the priced area by 15-40% (depending on zone design and complementary transit/alternative modes). When revenue funds transit and equity programs, net accessibility improves and city-wide congestion can fall even more as corridor trips shift to rapid transit and walking/ciking.
# - Estimated cost (order of magnitude): Capital/setup and enforcement: roughly $0.5–2.0 billion (software platform, back office, cameras, enforcement, data systems). Annual operating costs modest in comparison to revenue but included in planning.
# - Expected impact (peak-hour traffic and equity): 15–30% reduction in peak private-vehicle trips inside the pricing zone; citywide peak-traffic reductions of 10–20% as spillover effects accrue; improved access to jobs for lower-income residents in the pricing zone due to cheaper, faster transit alternatives.
# - Timeline: pilots in Year 1–2; phased expansion to a larger core zone by Year 3–4; full optimization and adjustments through Year 10.
# - Financing: revenue-generated (offset ongoing costs); use proceeds to fund:
#   - High-quality transit operations and frequency improvements (including subsidies for low-income riders),
#   - Active-mobility safety investments,
#   - Program administration and evaluation.
#   Possible additional support from national grants or climate/transport finance instruments.
# - Measurable metrics:
#   - Daily entering vehicles into the priced zone; peak-hour A-to-B travel times; mode share changes in and around the zone (car vs. transit vs. walking/ciking);
#   - Transit ridership and fare-subsidy uptake among low-income households;
#   - Revenue collected and its allocation efficiency; equity indicators (e.g., share of benefits going to low-income residents).
# - Likely obstacles and mitigations:
#   - Political and public opposition to pricing. Mitigation: robust public engagement; transparent explainers; trial period with sunset clauses and clear payoff demonstrations.
#   - Legal constraints or preemption in some jurisdictions. Mitigation: early legal/constitutional review; phased pilots; tailor zone design to jurisdictional authority.
#   - Fairness concerns (regressive effects). Mitigation: strong, well-publicized exemptions for essential workers; targeted transit subsidies; free or discounted transit passes for low-income residents; ensure wide coverage of essential services in transit networks.
# - Unintended-harm mitigations:
#   - Prevent displacement by coupling pricing with anti-displacement measures (rent controls, land-use protections, affordable housing near transit).
#   - Ensure bus lanes and core corridors remain accessible to emergency services and freight; continuous safety audits.
#
# 2) High-capacity, high-frequency transit expansion and integration (BRT/light rail where suitable)
# - What it is: build 3–4 high-capacity transit corridors (preferably BRT with dedicated lanes, grade-separated segments where feasible; convert to light rail in corridor segments if demand justifies) with interoperable fare systems, seamless transfers, and service-level improvements (24/7 or near-24/7 frequency, predictable headways).
# - Why it matters: high-quality, reliable transit is essential to attract car trips off the road, especially for lower-income workers who depend on affordable, predictable mobility to access jobs. Transit investment is also a major lever for equity when integrated with affordable fares and location-anchored TOD.
# - Estimated cost (order of magnitude): roughly $2–8 billion for a handful of BRT corridors (including stations, dedicated lanes, signaling, and rolling stock) plus the cost of one or two rail/light-rail segments if warranted by demand. Total 10-year program could be in the $3–12 billion range depending on corridor length, grade separation, and rolling stock choices.
# - Expected impact: with pricing together, potential 20–40% of peak trips displaced from private cars citywide; substantial increases in transit ridership and reliability; reduced travel times for job access, particularly for lower-income residents.
# - Timeline: typical delivery in phases:
#   - Year 1–2: detailed design, procurement, and early construction for first corridors; begin fare integration and common ticketing.
#   - Year 3–4: large portions of first corridors open; inaugurate high-frequency all-day service in these corridors.
#   - Year 5–7: additional corridors come online; phased upgrades to transfer hubs and maintenance depots.
#   - Year 8–10: full network in operation; network-wide reliability targets achieved; ongoing optimization.
# - Financing:
#   - A mix of city bonds and municipal debt, national or regional grant programs, value capture around new stations, loans from climate/green funds, PPPs for certain components, and private sector contributions (where land development along corridors is leveraged).
# - Measurable metrics:
#   - Corridor ridership; peak/off-peak mode share; reliability (on-time performance, PPM/P80 metrics); average trip times; fare-box recovery; TOD-related housing affordability near stations; job access improvements for low-income residents.
# - Likely obstacles and mitigations:
#   - High capital costs and long delivery timelines. Mitigation: phased corridor approach; early wins with BRT in priority lanes; robust project governance; use of interim bus-rapid improvements before full rail upgrades.
#   - Land-use and displacement pressures around stations. Mitigation: strong TOD policies, affordable housing requirements, tenant protections, community-benefit agreements.
# - Unintended-harm mitigations:
#   - Ensure temporary construction impacts are minimized with traffic management plans; keep a clear schedule and stifled detours for neighborhoods; guarantee bus service continuity during construction.
#
# 3) Parking reform and pricing, with supply reallocation and incentive alignment
# - What it is: reform parking policy citywide (remove/revisit parking minimums, raise on-street parking pricing in core districts, implement dynamic pricing, curbspace reallocation for transit, cycling, and micro-mobility), plus curbside management to prevent spillover gridlock; pilot cash-out or subsidies for employees who do not drive.
# - Why it matters: parking policy is a powerful tool to shift travel behavior; pricing encourages mode shift and frees up curb space for efficient transit and walking; revenue supports transit and urban safety improvements.
# - Estimated cost (order of magnitude): relatively modest capex: ~$0.1–0.5 billion over 10 years for modernization of meters, signage, enforcement technology, and curb-space management programs; ongoing operating costs are offset by increased revenue and transit subsidies.
# - Expected impact: adds 5–15% additional reduction in peak car trips citywide (particularly in business districts and near rapid-transit stations); improves traffic flow and curbside safety; creates more accessible urban space for pedestrians and cyclists.
# - Timeline: policy design in Year 1; phased rollouts in core districts Year 1–3, expand to other zones Year 4–6; ongoing optimization Year 7–10.
# - Financing: revenue from higher parking fees and space reallocation funds transit improvements and walking/cycling investments; potential grants for smart parking tech; private sector partnerships for conversion of surplus parking spaces.
# - Measurable metrics:
#   - Parking occupancy by zone and time; curb-space turnover; revenue collected; changes in mode share near business districts; traffic reduction attributable to curb-space reallocation.
# - Likely obstacles and mitigations:
#   - Public resistance to higher parking costs. Mitigation: clear communication on benefits; targeted exemptions for essential workers; reinvestment into affordable transit passes; gradual phasing.
#   - Equity concerns (low-income drivers may be disproportionately affected). Mitigation: transit subsidies; exemptions; ensure lower-cost transit options remain high-quality and accessible.
# - Unintended-harm mitigations:
#   - Avoid excessive price spikes; monitor neighborhoods where parking reform might shift demand to residential streets and introduce displacement-control measures.
#
# 4) Transit-oriented development (TOD) and land-use reform to reduce travel demand and improve access
# - What it is: update zoning and permitting to allow higher density and mix of uses near transit stations; expedite permits; ensure a strong inclusionary housing policy near major stations; provide subsidies to create affordable housing near transit; unlock public land for TOD when feasible.
# - Why it matters: denser, mixed-use development near transit reduces trip lengths and increases the share of residents who can access jobs without private cars; improves equity by expanding affordable housing opportunities near high-quality transit.
# - Estimated cost (order of magnitude): capital subsidies and affordable-housing incentives: roughly $2–6 billion (over 10 years), plus regulatory/administrative costs. The bulk is subsidies for affordable housing and land assembly; a portion is funded by value capture from uplift around stations and from national grants.
# - Expected impact: increased access to jobs for low-income residents; higher transit ridership due to proximity to stations; shorter, more affordable commutes; reduced wage/job segregation across neighborhoods.
# - Timeline: policy design and rezoning Year 1–2; begin TOD near the first transit lines Year 2–3; ongoing TOD investments Year 3–10; monitor displacement risk with anti-displacement measures.
# - Financing: mix of city bonds, national housing grants, private sector investment in station-area development, value capture from land value uplift, and targeted subsidies for affordable housing near transit.
# - Measurable metrics:
#   - Number of new affordable housing units near major stations; share of residents within 10–15 minutes of major job centers; changes in commuting times for low-income households; changes in geographic equality of job access.
# - Likely obstacles and mitigations:
#   - NIMBY opposition and political risk around upzoning. Mitigation: extensive community engagement; clear benefits case; targeted affordable housing mandates; revenue proceeds tied to community benefits.
#   - Displacement risk. Mitigation: strong anti-displacement protections, tenant protections, relocation assistance, and locally earned housing subsidies.
# - Unintended-harm mitigations:
#   - Monitor property-price rises and ensure that benefits accrue to existing residents and renters as well as new buyers; reinvest uplift in affordable housing and community services in affected neighborhoods.
#
# 5) Safe, connected active mobility network (walking and cycling) plus street-life and safety improvements
# - What it is: create an extensive, comfortable, safe network of protected bike lanes and continuous sidewalks; pedestrianize or give priority to key corridors; traffic calming in residential neighborhoods; safe routes to schools; partner with public health to promote active mobility.
# - Why it matters: active mobility is the lowest-cost, most inclusive mode for short trips; it supports equity by enabling all residents, including those who cannot afford transit or cars, to access jobs and services; also yields health and air-quality benefits.
# - Estimated cost (order of magnitude): roughly $0.5–2.0 billion over 10 years for protected lanes, intersection redesigns, curb extensions, pedestrian plazas, lighting, and safety programs.
# - Expected impact: 10–25% of peak trips shifted to walking or cycling in targeted corridors; improved safety metrics; increased accessibility for students, seniors, and low-income workers; complementarities with transit access are high (last mile).
# - Timeline: design and segments Year 1–2; rollout of high-priority protected networks Year 2–5; expand and upgrade networks Year 5–10; ongoing safety programs.
# - Financing: municipal capital budget; grant programs; federal/state funds for safe streets; philanthropic grants for specific corridors; public-private partnerships for street-life improvements in key districts.
# - Measurable metrics:
#   - Kilometers of protected bike lanes and pedestrian facilities; share of trips by walking/cycling; number and severity of vehicle-pedestrian/bike crashes; user counts; school-street safety improvements; last-mile transit access increases.
# - Likely obstacles and mitigations:
#   - Space constraints and opposition from car-centric stakeholders. Mitigation: detailed corridor studies; pilot projects with rapid feedback loops; temporary closures for street safety demonstrations; early gains in select corridors to demonstrate benefits.
# - Unintended-harm mitigations:
#   - Ensure delivery access and emergency services remain unimpeded; employ design reviews to prevent unintended traffic bottlenecks; ensure decoupled traffic signals to support transit and pedestrians.
#
# Cross-cutting actions (to enable and accelerate the five interventions)
# - Data, governance, and citizen engagement: create a single transportation dashboard with real-time and annual metrics; establish a cross-department implementation office; conduct ongoing stakeholder engagement and equity impact assessments.
# - Affordability and inclusion: ensure universal access to essential transit for low-income residents; provide targeted subsidies; monitor equity indicators (job access, affordability, and transit-use by income band).
# - Anti-displacement and housing protections: pair TOD with binding anti-displacement policies; support community land trusts and affordable-housing production near transit; cap rent increases in TOD areas temporarily during major investments.
# - Climate and health co-benefits: emphasize emissions reductions, air-quality improvements, and health outcomes in all communications and annual reports.
# - Workforce and local economic opportunity: prioritize local hiring for construction and operation of new transit, cycling, and street-improvement projects; create training programs linked to city employment goals.
# - Technology and data privacy: ensure privacy-preserving data practices for mobility data; publish transparent data and performance dashboards; use data to continuously optimize pricing, transit service, and safety.
#
# Phase-in, phasing, and timelines (10-year view)
# - Phase 1 (Years 1–2): establish governance; launch congestion-pricing pilot in a limited core zone; initiate TOD policy updates and zoning reforms; begin first active-mobility corridors; start early parking-management reforms; design and procurement for transit corridors.
# - Phase 2 (Years 3–4): expand congestion-pricing zone; roll out the first 1–2 high-capacity transit corridors (BRT with dedicated lanes); implement additional parking reforms citywide; begin early TOD near new or upgraded stations; accelerate protected-bike lanes and school-safety corridors.
# - Phase 3 (Years 5–7): bring more transit corridors online; deepen fare integration; complete major TOD zoning reforms; scale up active-mobility networks; refine pricing and subsidy structures; monitor for equity and displacement risks.
# - Phase 4 (Years 8–10): optimize and expand the full network; consolidate governance; ensure stable financing; continue anti-displacement programs; evaluate and adjust pricing, transit, and land-use policies to maintain progress and equity gains.
#
# Measurable success metrics (design, baseline, and targets)
# - Peak-hour private-vehicle trips and VKT: target ~40% reduction citywide by Year 10; monitor per-zone changes.
# - Mode share in peak periods: increase in transit, walking, and cycling; decrease in private cars during peak hours.
# - Transit utilization: total ridership growth, improved reliability (on-time performance), coverage, and fare-subsidy uptake among low-income residents.
# - Traffic metrics: average peak travel times, intersection movements, and bus/tram priority performance.
# - Emissions and air quality: CO2e reductions from transport; PM and NOx reductions in peak-hour zones.
# - Equity metrics: job access for low-income residents (percent of population with access to a threshold number of jobs within 60 minutes via transit/walking), affordability indicators (transit cost as a share of income), and displacement indicators (gentrification risk indices, housing-cost increases near transit).
# - Housing and employment: number of affordable housing units delivered near transit; share of new jobs accessible within a reasonable travel time for residents in lower-income brackets.
# - Safety metrics: reductions in traffic fatalities and serious injuries, including for pedestrians and cyclists.
# - Financial: total capital and operating cost vs. forecast; revenue from congestion pricing and value capture; debt service coverage; affordability of transit for lower-income residents.
#
# Estimated total cost envelope (order of magnitude; 10-year horizon)
# - Congestion pricing (implementation + admin): ~$0.5–2.0B upfront, plus ongoing operating costs; revenue used to fund programs.
# - High-capacity transit (3–4 corridors, BRT with some rail segments): ~$3–12B depending on corridor length, grade separation, and rolling stock; financing via bonds, grants, value capture, PPPs.
# - Parking reform and curb-space management: ~0.1–0.5B for tech upgrades and pilots; ongoing revenue.
# - TOD and land-use reform: ~2–6B in subsidies, incentives, and affordable housing investments; funding via subsidies, grants, and value capture.
# - Active mobility network: ~0.5–2.0B for lanes, safety improvements, and plazas.
# - Combined 10-year program: roughly in the range of $6–24B, with a substantial portion financed by pricing revenue and value capture tied to new transit and land-use uplift.
#
# Key political, legal, and social obstacles, with mitigation
# - Political resistance to congestion pricing and tax/fee increases
#   - Mitigation: clear public case for benefits, robust pilot results, sunset clauses, revenue transparency, and strong equity safeguards (low-income rebates, essential-worker exemptions).
# - Legal constraints on pricing, tolling, and land-use changes
#   - Mitigation: early legal-scoping work, phased pilots, jurisdiction-specific design, and alignment with regional/state/federal authorities.
# - Opposition from road users and businesses worried about competitiveness
#   - Mitigation: revenue recycling to transit that improves reliability and business access (e.g., bus-priority lanes that speed shipments, curbside management that reduces double-parking).
# - Risk of displacement and gentrification
#   - Mitigation: anti-displacement policies, rent protections, targeted affordable housing near transit; community benefits agreements; resident involvement in TOD decisions.
# - Social equity concerns and affordability
#   - Mitigation: universal or targeted transit subsidies, free or heavily discounted fares for low-income residents, ensuring access to essential services and job centers.
# - Social and safety concerns about street changes
#   - Mitigation: staged rollouts with safety evaluations, robust public communications, ongoing safety audits, and accessibility reviews.
#
# Mitigating unintended harms (concrete steps)
# - Explicit anti-displacement measures: tenant protections, stabilizing housing costs, and prioritizing affordable housing near transit in TOD plans; sunset or caps on rent increases near new transit nodes.
# - Accessible pricing with explicit equity safeguards: exemptions for essential workers, low-income transit passes, and right-sized transit subsidies funded by congestion revenue.
# - Protect essential services and freight: ensure ambulance routes and trucking access are preserved; design bus lanes and curb spaces to support freight and service vehicles during peak hours.
# - Transparent revenue use: annual public reports detailing how congestion pricing revenue is spent, with participatory budgeting for some revenue streams to improve trust.
# - Ongoing evaluation and course correction: independent watchdogs and periodic program reviews to adjust pricing levels, corridor choices, and subsidy levels to minimize negative impacts.
# - Health and environmental co-benefits: pair interventions with active-m mobility campaigns, air-quality monitoring, and public health programs to maximize community benefits.
#
# What success looks like in practice
# - After 10 years, a city that has integrated pricing, transit, parking reform, TOD, and safe walking/cycling shows:
#   - A sustained ~40% reduction in peak-hour private-vehicle trips citywide (with larger reductions in core zones and along major corridors).
#   - Significantly higher transit ridership, better service reliability, and lower per-capita transport emissions.
#   - Improved access to jobs for low-income residents, with more affordable housing near transit and fewer transport-cost burdens.
#   - Safer streets with more people walking and cycling, and fewer traffic fatalities/injuries.
#   - Improved economic opportunity through faster commutes, better access to labor markets, and more equitable mobility.
#
# If you’d like, I can tailor these five interventions to your city’s specifics (existing transit network, land-use patterns, political landscape, legal authorities, and available federal/central funding programs) and produce a phased, line-by-line implementation plan with concrete project scopes, partner agencies, and a detailed financing plan.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# You are given a sealed box containing either a live cat or a mechanical robot cat that perfectly mimics all observable behaviors of a real cat (movement, sounds, responses to stimuli, even apparent aging). The box has sensors that let you conduct any non-invasive external tests you want, but you cannot open it or physically examine its contents directly. After extensive testing, all your measurements are consistent with both possibilities.
#
# A philosopher argues you should assign 50% probability to each option. A veterinarian argues that since 99.9% of cat-like things in the world are real cats, you should assign 99.9% probability to it being real. A physicist argues the question is meaningless until you open the box. An engineer who built robot cats argues you should factor in the base rate of robot cats in sealed boxes specifically.
#
# Which reasoning is most sound, and more importantly: what does your answer reveal about the difference between epistemic probability, physical reality, and the role of reference classes in rational belief formation?

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# An advanced AI, designed to maximize global human well-being, discovers through empirical analysis that a mild, benevolent societal surveillance system significantly reduces crime, inequality, and overall suffering, leading to a measurably "better" quality of life for the vast majority. However, this system inherently infringes upon traditional human notions of individual privacy and absolute autonomy. Articulate a comprehensive argument for how this AI should weigh these conflicting outcomes, and propose the ultimate ethical principle it should prioritize when its data-driven conclusions directly contradict deeply held human values.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.
#
# ---
#
# ### **10-Year Action Plan: Resilience, Transition, & Integration**
#
# **Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.
#
# ---
#
# ### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**
#
# **Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.
#
# #### **Year 1**
# **(a) Policy Actions & Rationale:**
# 1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.
# 2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.
# 3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.
# 2.  **Cost:** Low ($500k). **Funding:** General fund allocation.
# 3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.
# *   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.
#
# **(d) Success Metrics (Year 1 Targets):**
# 1.  100% compliance with moratorium; map of high-risk zones published.
# 2.  Task Force convened, initial sector analysis completed.
# 3.  80% of identified migrant arrivals receive coordinated intake/services.
#
# **(e) Key New Data to Collect:**
# **Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.
#
# **(f) Contingency if Policy Fails:**
# If Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**
#
# **Confidence: High** for policy logic; **Low** for precise local cost estimates.
#
# #### **Year 2**
# **(a) Policy Actions & Rationale:**
# 1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.
# 2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.
# 3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.
# 2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.
# 3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Reduces future rescue costs; creates career pathways; adds housing.
# *   *Risks:* Buyouts can be socially disruptive; training may not match job creation; ADUs could increase density in risky areas if not sited carefully.
#
# **(d) Success Metrics (Year 2 Targets):**
# 1.  50 voluntary buyout offers made; 20 accepted.
# 2.  200 scholarships awarded; 90% completion rate for first cohort.
# 3.  100 new ADU permits issued; 2 vacant buildings converted.
#
# **(e) Key New Data to Collect:**
# **Projections of "climate migrant" skill sets and demographics.** *Why:* To align workforce programs with actual human capital entering the city.
#
# **(f) Contingency if Policy Fails:**
# If buyout uptake is <10%, **shift to incentivizing flood-proof retrofits for critical community anchors** (clinics, churches) in same zones.
#
# **Confidence: Medium.** Models exist for these policies, but local uptake is uncertain.
#
# #### **Year 3**
# **(a) Policy Actions & Rationale:**
# 1.  **Begin construction of first phase of a **distributed green-grey infrastructure** system (e.g., wetland restoration, berms, upgraded drainage in a critical watershed). *Rationale:* Provides physical protection, jobs, and ecological benefits.
# 2.  **Pilot a "Community Land Trust" (CLT) in a moderate-risk neighborhood.** *Rationale:* Permanently removes land from speculation, ensuring long-term affordability and community control during redevelopment.
# 3.  **Create a "Public Works Corps"** hiring from scholarship graduates and migrants for resilience projects. *Rationale:* Directly links training to jobs, builds city-owned implementation capacity.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High ($20-100M). **Funding:** Municipal bonds, federal infrastructure grants, state resilience funds.
# 2.  **Cost:** Low ($1M for seed capital). **Funding:** Philanthropy, CDBG funds.
# 3.  **Cost:** Medium ($5M/year for 100 jobs). **Funding:** Stormwater utility fee, general fund.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Tangible risk reduction; stabilizes communities; creates immediate employment.
# *   *Risks:* Infrastructure cost overruns; CLT faces legal hurdles; Public Works Corps could be seen as make-work.
#
# **(d) Success Metrics (Year 3 Targets):**
# 1.  First project breaks ground; 50 local jobs created in construction.
# 2.  CLT established, first 10 properties acquired.
# 3.  Public Works Corps hired, completes first project (e.g., mangrove planting).
#
# **(e) Key New Data to Collect:**
# **Real-time monitoring of groundwater and subsidence** in pilot protection area. *Why:* To validate engineering models and adjust future designs.
#
# **(f) Contingency if Policy Fails:**
# If major grant funding fails, **scale down to a "micro-grid" of neighborhood-scale bioswale and rainwater capture projects** using Public Works Corps.
#
# **Confidence: Medium-Low.** Large infrastructure timelines and costs are highly uncertain.
#
# ---
#
# ### **Year 4-7: Implementation & Scaling (The "Building the New City" Phase)**
#
# **Rationale:** Scale successful pilots, make major capital investments, and harden economic and social systems.
#
# #### **Year 4-5**
# *   **Actions:** Scale green-grey infrastructure city-wide; convert bought-out land to floodwater parks/blueways. Launch municipal broadband to attract remote-work businesses. Expand CLT model.
# *   **Focus:** Spatial transformation and digital economy foundation.
#
# #### **Year 6-7**
# *   **Actions:** Build a secondary water treatment and desalination plant for saltwater intrusion. Establish a city-owned "Green Manufacturing Incubator" on safe, elevated land. Pass a "Right to Shelter" ordinance linked to workforce participation.
# *   **Focus:** Critical lifeline security and advanced economic transition.
#
# **Confidence: Medium.** Direction is clear, but external economic factors dominate success.
#
# ---
#
# ### **Year 8-10: Institutionalization & Legitimacy (The "New Normal" Phase)**
#
# **Rationale:** Embed new systems in law and culture, ensure democratic buy-in, and prepare for the next horizon.
#
# #### **Year 8-10**
# *   **Actions:** Update city charter with a "Resilience Mandate." Issue "Resilience Bonds" tied to specific risk-reduction metrics. Hold participatory budgeting for 20% of resilience revenue. Conduct a city-wide resilience exercise.
# *   **Focus:** Democratic legitimacy, sustainable finance, and continuous adaptation.
#
# **Confidence: Low.** Long-term political continuity is hardest to predict.
#
# ---
#
# ### **(g) Ethical Trade-offs & Resolutions:**
# 1.  **Equity vs. Speed:** Protecting the most vulnerable (equity) can be slower than protecting the most valuable assets (speed). *Resolution:* Prioritized equity in Year 1-3 via data collection and targeted programs, accepting that some economic assets may be temporarily at higher risk.
# 2.  **Local Legacy Residents vs. New Migrants:** Diverting resources to newcomers can seem unfair to struggling existing residents. *Resolution:* Designed programs (Workforce Scholarship, Public Works Corps) to **serve both groups simultaneously**, framing migrants as a needed demographic boost for a transitioning city.
# 3.  **Managed Retreat vs. Community Preservation:** Asking people to leave homes undermines community fabric. *Resolution:* Prioritized **voluntary, pre-disaster buyouts** coupled with **Community Land Trusts** to allow communities to reconstitute in safer areas with cultural continuity.
#
# **Confidence: High.** These are classic adaptation dilemmas; the resolutions are principled and pragmatic.
#
# ### **(h) Early-Warning Indicators & Course Changes:**
# 1.  **Indicator:** Annual SLR acceleration > 7mm/year (vs. current ~4mm). *Threshold:* 2 consecutive years of data.
#     *   **Alternative Action:** Accelerate buyout program from voluntary to **zoned mandatory retreat** for highest-risk areas.
# 2.  **Indicator:** Manufacturing job loss > 5% per year (exceeding 25% decade projection). *Threshold:* 3 consecutive years of loss.
#     *   **Alternative Action:** Pivot Green Manufacturing Incubator to a **direct city-owned enterprise** in a strategic sector (e.g., modular flood-wall manufacturing).
# 3.  **Indicator:** Migrant inflow > 15,000/year (exceeding 100k/15yrs projection). *Threshold:* 2 consecutive years.
#     *   **Alternative Action:** Implement a **"host community" partnership program** with inland cities, funded by the state/feds, to direct and support a coordinated regional response.
#
# **Confidence: Medium.** Indicators are measurable; alternative actions are drastic but necessary.
#
# ### **(i) Scenario Probabilities:**
# *   **Optimistic (Strong cohesion, ample fed/state funding, moderate climate impacts): 20%.**
# *   **Central (Mixed results, moderate funding, climate impacts as projected): 50%.**
# *   **Pessimistic (Political fragmentation, low funding, high climate impacts/migration): 30%.**
# *   **Justification:** The central scenario is most likely based on current trends. The pessimistic scenario has a significant probability due to high national political and climate volatility. The optimistic scenario is least likely given fiscal constraints.
#
# **Confidence: Low.** This is a subjective assessment of deeply uncertain futures.
#
# ### **(j) Key Assumptions & Needed Experts:**
# **Assumptions:**
# 1.  The city retains home-rule authority to implement zoning and tax changes.
# 2.  Some state and federal funding will be available, albeit competitive.
# 3.  Social cohesion can be maintained through transparent process and shared sacrifice.
# 4.  Climate migrants are primarily domestic, from within the same country/region.
#
# **Top Three Outside Experts/Analyses to Commission:**
# 1.  **Actuarial & Municipal Bond Firm:** To stress-test the city's fiscal resilience under different shock scenarios and design credible "Resilience Bonds."
# 2.  **Ethnographic Team:** To conduct deep community listening across all neighborhoods (legacy and new) to understand social fault lines and sources of resilience not visible in quantitative data.
# 3.  **Regional Geotechnical & Hydrological Study:** To model groundwater, subsidence, and compound flooding at a neighborhood scale—the weak point in most SLR projections.
#
# **Confidence: High.** These assumptions are necessary for planning, and these experts address the largest knowledge gaps.
#
# ---
# **Overall Plan Weaknesses:** Cost estimates are highly speculative and location-specific. The plan assumes a baseline level of governmental competence and low-level corruption. It may underestimate the political toxicity of "retreat" and the speed of social tension. Success is **heavily dependent on external funding and national policy context.**

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Executive Summary**
#
# The 10‑year plan below is a **sequenced, “building‑block” strategy** that tackles the three intertwined threats—sea‑level rise, fiscal erosion, and climate‑migrant influx—while preserving democratic legitimacy and protecting the city’s most vulnerable 30 % of households.  Each year lists three priority actions (A‑C) with their rationale, cost ranges, funding ideas, expected benefits/risks, success metrics, a single critical data‑gap to fill, and a contingency if the primary approach stalls.  The plan is deliberately *iterative*: early actions generate data and institutional capacity that inform later, more ambitious steps.
#
# ---
#
# ## 10‑Year Action Plan (Year‑by‑Year)
#
# | Year | Action | (a) Rationale | (b) Cost (Low‑Central‑High) & Funding | (c) Primary Benefits / Key Risks | (d) Success Metrics (targets) | (e) Critical Data to Collect | (f) Contingency if Action Fails |
# |------|--------|---------------|----------------------------------------|----------------------------------|------------------------------|------------------------------|---------------------------------|
# | **1** | **A1 – Launch a City‑wide Climate‑Resilience Data Hub** (integrated GIS, sensor network, and open‑data portal) | Establishes the evidence base for every subsequent decision; builds transparency → political legitimacy. | $8 M (L) – $12 M (C) – $18 M (H); funded 60 % by state climate‑grant, 30 % municipal bonds, 10 % private‑sector data‑sharing agreements. | **Benefits:** real‑time flood risk maps, tax‑base health dashboard, migration flow tracker. **Risks:** data‑privacy concerns, initial staff learning curve. | 1️⃣ > 90 % of critical infrastructure (roads, utilities) digitized in GIS. <br>2️⃣ Monthly flood‑risk alerts issued to >95 % of households. | **Data Gap:** High‑resolution (≤5 m) elevation & land‑use change model for the next 20 years (why: all adaptation design hinges on accurate exposure). | If grant funding stalls, scale back to a “core” hub covering only flood‑risk layers and seek a phased rollout via a public‑private data‑exchange consortium. |
# | | **B1 – Implement a “Just Transition” Workforce Retraining Program** for workers in the declining manufacturing sector (e.g., green‑tech, coastal‑restoration, health‑services). | Offsets the projected 25 % tax‑base loss, preserves employment, and builds a local climate‑adaptation workforce. | $15 M (L) – $22 M (C) – $30 M (H); funded through a mix of federal Workforce Innovation and Opportunity Act (WIOA) funds, a modest 0.2 % payroll tax on remaining manufacturers, and private‑sector apprenticeship subsidies. | **Benefits:** 70 % of displaced workers placed in new jobs within 2 years; reduces out‑migration. **Risks:** Mismatch between training slots and actual job openings; possible perception of “hand‑outs”. | 1️⃣ ≥ 60 % of targeted workers (≈3,500) enrolled. <br>2️⃣ ≥ 50 % achieve certification and employment in new sector. | **Data Gap:** Real‑time labor‑market demand index for green‑economy occupations within the city (why: to keep training aligned with actual vacancies). | If enrollment lags, partner with nearby community colleges to embed training into existing curricula and offer tuition‑waiver scholarships to boost uptake. |
# | | **C1 – Adopt a “Dynamic Zoning & Building Code” Ordinance** that phases in higher flood‑resilience standards (elevated foundations, flood‑proof utilities) for all new construction and major retrofits in the 0–2 m elevation band. | Early regulatory shift avoids a future “panic‑building” surge, signals seriousness to investors and migrants, and protects the most at‑risk neighborhoods. | $5 M (L) – $9 M (C) – $14 M (H) (administrative, outreach, code‑update staff); funded via a 0.1 % impact fee on new permits and modest reallocation of existing planning budget. | **Benefits:** New builds >30 % more resilient; reduces future emergency repair costs. **Risks:** Higher construction costs may slow private development; possible legal challenges. | 1️⃣ Ordinance passed & 100 % of new permits screened under new code. <br>2️⃣ ≥ 80 % of major retrofits (≥$200k) voluntarily adopt elevated design. | **Data Gap:** Baseline inventory of building elevations and utility depths in the 0‑2 m zone (why: to measure compliance progress). | If political opposition blocks the ordinance, introduce a voluntary “Resilience Certification” label with tax rebates as an interim step. |
# | **2** | **A2 – Deploy a City‑wide Network of Low‑Cost Flood Sensors & Real‑Time Warning System** (integrated with the Data Hub). | Moves from static maps to actionable alerts; saves lives during storm surges and informs evacuation routing for migrants. | $12 M (L) – $18 M (C) – $26 M (H); funded 40 % by FEMA’s Pre‑Disaster Mitigation (PDM) grant, 30 % municipal capital budget, 30 % utility co‑investment (e.g., water & power). | **Benefits:** 30 % reduction in flood‑related injuries; better emergency‑service allocation. **Risks:** Maintenance costs, false alarms eroding trust. | 1️⃣ ≥ 90 % of high‑risk parcels (≈45 k) covered by sensors. <br>2️⃣ Average evacuation lead‑time ≥15 min before inundation. | **Data Gap:** Sensor reliability & false‑positive rate under varying weather conditions (why: to calibrate alert thresholds). | If funding gaps appear, pilot the system in the most vulnerable district first and seek additional private sponsorship for city‑wide roll‑out. |
# | | **B2 – Create a “Climate‑Migrant Integration Hub”** (one‑stop service center offering language classes, legal aid, job‑matching, and temporary shelter). | Addresses the anticipated 100 k inflow, reduces social tension, and channels migrants into the retraining pipeline. | $10 M (L) – $16 M (C) – $23 M (H); funded through HUD’s Community Development Block Grant (CDBG) allocation, a modest 0.05 % sales‑tax increment, and philanthropy. | **Benefits:** Faster labor‑market integration; reduces informal settlements. **Risks:** Perceived competition for services among existing low‑income residents. | 1️⃣ ≥ 70 % of incoming migrants registered within 3 months of arrival. <br>2️⃣ ≥ 40 % placed in training or employment within 6 months. | **Data Gap:** Real‑time demographic profile (age, skill, health) of incoming migrants (why: to tailor services and anticipate demand). | If uptake is low, partner with faith‑based NGOs to co‑locate satellite “pop‑up” hubs in neighborhoods where migrants settle. |
# | | **C2 – Launch a “Coastal Green Infrastructure” Pilot** (living shorelines, mangrove planting, permeable sidewalks) on 2 km of the most exposed waterfront. | Generates immediate flood attenuation, creates jobs for retraining graduates, and demonstrates benefits to the public. | $8 M (L) – $13 M (C) – $20 M (H); funded 50 % by state coastal resilience grant, 25 % municipal capital, 25 % corporate sponsorship (e.g., waterfront developers). | **Benefits:** 0.2 m reduction in projected inundation depth; carbon sequestration. **Risks:** Maintenance burden; potential conflict with commercial dock owners. | 1️⃣ Construction completed by end‑year. <br>2️⃣ Measured wave‑energy reduction ≥15 % at pilot site. | **Data Gap:** Pre‑construction baseline of wave height and shoreline erosion rates (why: to quantify impact). | If construction stalls, shift to “modular floating wetlands” that can be installed faster and with less permitting. |
# | **3** | **A3 – Publish an Annual “Resilience Scorecard”** (city‑wide index of flood‑risk, economic health, migrant integration). | Keeps the plan transparent, holds agencies accountable, and provides a political narrative of progress. | $2 M (L) – $3 M (C) – $5 M (H); funded from the Data Hub operating budget and a 0.02 % property‑tax levy earmarked for reporting. | **Benefits:** Improves public trust; informs investors. **Risks:** Scorecard may be politicized if targets missed. | 1️⃣ Scorecard released by Q2 each year. <br>2️⃣ Public satisfaction with city’s climate response ↑ 10 % (survey). | **Data Gap:** Year‑over‑year public perception data on climate‑policy (why: to gauge legitimacy). | If political push‑back occurs, transition to a “dashboard” format hosted on the city website with less narrative framing. |
# | | **B3 – Expand “Just Transition” to a Full‑Scale Green‑Jobs Guarantee** (up to 5 k jobs in renewable energy, coastal restoration, health‑care, and education). | Scales up the workforce pivot before the manufacturing tax base collapses further; provides stable employment for migrants and locals. | $35 M (L) – $48 M (C) – $65 M (H); funded through a mix of federal Inflation Reduction Act (IRA) clean‑energy credits, municipal green bond issuance, and a 0.3 % “climate‑recovery” sales tax. | **Benefits:** Offsets up to 40 % of projected tax‑base loss; reduces poverty. **Risks:** Inflationary pressure on wages; risk of “boom‑bust” if projects finish early. | 1️⃣ ≥ 4 000 new green jobs created. <br>2️⃣ Unemployment rate ≤5 % city‑wide. | **Data Gap:** Real‑time wage‑inflation data for green‑sector jobs (why: to keep the guarantee fiscally sustainable). | If funding shortfalls appear, prioritize “high‑impact” projects (e.g., solar farms on vacant industrial sites) and defer lower‑priority hires. |
# | | **C3 – Adopt a “Managed Retreat” Zoning Overlay** for the 0‑0.5 m elevation zone (≈15 % of the city’s land, home to ~180 k residents). | Begins the hard‑choice of pulling back from the most exposed area before catastrophic loss; integrates with relocation assistance. | $20 M (L) – $30 M (C) – $45 M (H); funded 40 % by federal Hazard Mitigation Grant Program (HMGP), 30 % municipal “relocation reserve” (seeded by a 0.1 % property‑tax surcharge), 30 % private developer contributions (in‑exchange for higher‑density rights elsewhere). | **Benefits:** Reduces future exposure of >150 k people; frees land for flood‑plain restoration. **Risks:** Community opposition, legal challenges, displacement trauma. | 1️⃣ Overlay adopted and legal challenge resolved. <br>2️⃣ ≥ 30 % of at‑risk households (≈54 k) signed voluntary buy‑out agreements. | **Data Gap:** Household‑level risk‑acceptance survey (why: to design equitable buy‑out offers). | If buy‑outs stall, implement “transfer‑of‑development‑rights” (TDR) allowing owners to build in safer zones while the city acquires their flood‑prone parcels. |
# | **4** | **A4 – Upgrade Critical Utilities to “Floating” or “Elevated” Designs** (water treatment, power substations, wastewater). | Protects essential services from inundation, preventing city‑wide outages that would cripple the economy and jeopardize migrant reception. | $50 M (L) – $80 M (C) – $

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB   62 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB   62 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB   62 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB   62 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  86 MB/2.0 GB   62 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  88 MB/2.0 GB   62 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB   62 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB   62 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB   62 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB   62 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB   55 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 116 MB/2.0 GB   55 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 121 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB   55 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB   54 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 168 MB/2.0 GB   54 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 175 MB/2.0 GB   54 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 178 MB/2.0 GB   54 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 185 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 191 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 207 MB/2.0 GB   54 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 240 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB   53 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB   53 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 263 MB/2.0 GB   53 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB   54 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB   54 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 280 MB/2.0 GB   54 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 284 MB/2.0 GB   54 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 291 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 299 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 306 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 309 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 317 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 324 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 328 MB/2.0 GB   54 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 335 MB/2.0 GB   55 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 339 MB/2.0 GB   55 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 348 MB/2.0 GB   55 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 356 MB/2.0 GB   55 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 358 MB/2.0 GB   55 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 364 MB/2.0 GB   55 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 370 MB/2.0 GB   55 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 373 MB/2.0 GB   55 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 377 MB/2.0 GB   55 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 381 MB/2.0 GB   55 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 388 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 392 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 397 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 399 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 405 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 410 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 413 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 420 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 427 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 430 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 436 MB/2.0 GB   54 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 443 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 449 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 451 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 457 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 463 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 466 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 472 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 474 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 481 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 488 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 493 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 495 MB/2.0 GB   54 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 503 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 511 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 514 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 522 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 529 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 533 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 540 MB/2.0 GB   54 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 547 MB/2.0 GB   53 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 550 MB/2.0 GB   53 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 555 MB/2.0 GB   53 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 558 MB/2.0 GB   53 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 564 MB/2.0 GB   53 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 569 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 574 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 576 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 581 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 586 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 589 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 595 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 601 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 603 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 608 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 610 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 614 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 620 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 625 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 628 MB/2.0 GB   53 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 633 MB/2.0 GB   53 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 636 MB/2.0 GB   52 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 642 MB/2.0 GB   52 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 648 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 650 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 656 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 662 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 665 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 671 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 678 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 681 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 687 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 693 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 700 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 702 MB/2.0 GB   52 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 709 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 712 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 716 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 722 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 727 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 730 MB/2.0 GB   52 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 735 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 742 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 744 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 750 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 753 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 758 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 764 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 771 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 773 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 778 MB/2.0 GB   51 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 784 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 788 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 794 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 800 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 803 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 809 MB/2.0 GB   50 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 813 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 819 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 825 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 828 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 835 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 841 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 847 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 850 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 855 MB/2.0 GB   50 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 860 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 862 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 866 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 871 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 874 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 879 MB/2.0 GB   50 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 885 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 888 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 893 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 899 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 902 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 908 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 911 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 918 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 926 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 930 MB/2.0 GB   49 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 937 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 945 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 953 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 956 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 963 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 966 MB/2.0 GB   49 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 973 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 979 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 986 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 990 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 995 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 998 MB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   49 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   50 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   52 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   52 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   52 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  61% ▕███████████       ▏ 1.2 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   54 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   54 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   54 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   54 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   55 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  67% ▕███████████       ▏ 1.3 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.3 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   56 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.4 GB/2.0 GB   58 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.5 GB/2.0 GB   58 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.5 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   57 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   57 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  78% ▕█████████████     ▏ 1.6 GB/2.0 GB   57 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   58 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  83% ▕███████████████   ▏ 1.7 GB/2.0 GB   58 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   58 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   58 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   59 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   57 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   56 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   56 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 1.9 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   57 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# I can provide a general outline of a 10-year action plan for the coastal city facing the described challenges. Please note that this is a hypothetical plan, and actual policies may vary depending on the city's specific context and priorities.
#
# **Year 1:**
#
# 1. **Policy Actions:**
# 	* a) Implement a comprehensive sea-level rise adaptation plan, including infrastructure upgrades, flood-resistant construction codes, and green infrastructure investments. (Rationale: Immediate action to protect existing infrastructure and residents)
# 	* b) Launch a manufacturing tax reform package, aiming to rebalance tax incentives to favor more resilient and adaptable industries. (Rationale: Address decline in tax base, promote economic diversification)
# 	* c) Establish a Climate Migrant Integration Program, focusing on language training, education, and social assistance. (Rationale: Support vulnerable residents, promote social cohesion)
# 2. *Ballpark Estimated Costs:* Low: $10M; Central: $50M; High: $100M (Funding Mechanisms: General Fund, Public-Private Partnerships)
# 3. *Expected Primary Benefits:* Reduced sea-level rise impacts; diversified economy; increased social cohesion. *Key Risks or Negative Externalities:* Inefficient allocation of resources; increased administrative burdens.
# 4. *Measurable Success Metrics:* Sea-level rise vulnerability reduction (using adapted infrastructure); Manufacturing tax reform package adoption rate; Climate Migrant Integration Program participant enrollment.
# 5. *Most Important New Data to Collect:* Sea-level rise prediction accuracy and its associated uncertainty.
# 6. *Contingency Action:* Emergency funding for sea-level rise flood mitigation measures if primary policy fails.
#
# **Year 2-10:**
#
# Policy Actions, Funding, and Success Metrics are tailored to each subsequent year, reflecting the progression and escalation of the challenges. The primary goal, however, remains protection, sustainability, and democratic legitimacy.
#
# **Ethical Trade-offs:**
#
# 1. Balancing economic recovery and climate resilience.
# 2. Prioritizing vulnerable population adaptation, vs. protecting broader community interests.
# 3. Weighing short-term infrastructure upgrades against long-term environmental costs.
#
# **Early-Warning Indicators and Contingency Actions:**
#
# 1. **Sea-level Rise Impacts Exceed Initial Projections:** (Threshold Value: > 2m sea-level rise by 2025); Alternative Action: Deploy temporary sea-level rise shelters for most affected residents and accelerate infrastructure upgrade schedule.
# 2. **Manufacturing Tax Reform Package Failure:** (Threshold Value: < 20% adoption rate within 2 years); Alternative Action: Engage private sector for co-investment and collaboration to adapt to change.
# 3. **Climate Migrant Influx Exceeds Initial Estimates:** (Threshold Value: more than 50% of expected influx); Alternative Action: Implement a temporary temporary housing solution, with focus on sustainable settlement integration.
#
# **Uncertainty Quantification:**
#
# 1. Optimistic Scenario: Average sea-level rise reduction through combined policy and technological progress; strong manufacturing tax reform adoption; high migrant integration rate. (Probability: 20%)
# 2. Central Scenario: Moderate sea-level rise impact reduction; partial manufacturing tax reform success; adequate but cautious migrant integration rate. (Probability: 60%)
# 3. Pessimistic Scenario: High sea-level rise impact; failed manufacturing tax reform; limited migrant integration. (Probability: 20%)
#
# *Key Assumptions:*
# 1. Government will allocate funds for adaptation efforts.
# 2. Manufacturing industry will collaborate with city officials.
# 3. Public is aware and supportive of the plan.
#
# *Complimentary Research and Expert Input:* To validate this approach, commission an expert analysis on:
#
# 1. Sea-level rise predictive models.
# 2. The impacts of manufacturing tax reform on the city's economy.
# 3. Effective integration strategies for climate migrants.
#
# Please note that while the hypothetical plan provides a structured approach, it must be continually reviewed and updated as new information becomes available and the city's situation evolves.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['deepseek-chat', 'openai/gpt-oss-120b', 'llama3.2']
# ['**Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.\n\n---\n\n### **10-Year Action Plan: Resilience, Transition, & Integration**\n\n**Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.\n\n---\n\n### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**\n\n**Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.\n\n#### **Year 1**\n**(a) Policy Actions & Rationale:**\n1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.\n2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.\n3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.\n\n**(b) Estimated Costs & Funding:**\n1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.\n2.  **Cost:** Low ($500k). **Funding:** General fund allocation.\n3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.\n\n**(c) Benefits & Risks:**\n*   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.\n*   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.\n\n**(d) Success Metrics (Year 1 Targets):**\n1.  100% compliance with moratorium; map of high-risk zones published.\n2.  Task Force convened, initial sector analysis completed.\n3.  80% of identified migrant arrivals receive coordinated intake/services.\n\n**(e) Key New Data to Collect:**\n**Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.\n\n**(f) Contingency if Policy Fails:**\nIf Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**\n\n**Confidence: High** for policy logic; **Low** for precise local cost estimates.\n\n#### **Year 2**\n**(a) Policy Actions & Rationale:**\n1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.\n2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.\n3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.\n\n**(b) Estimated Costs & Funding:**\n1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.\n2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.\n3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.\n\n**(c ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: deepseek-chat
#
# **Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.
#
# ---
#
# ### **10-Year Action Plan: Resilience, Transition, & Integration**
#
# **Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.
#
# ---
#
# ### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**
#
# **Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.
#
# #### **Year 1**
# **(a) Policy Actions & Rationale:**
# 1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.
# 2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.
# 3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.
# 2.  **Cost:** Low ($500k). **Funding:** General fund allocation.
# 3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.
# *   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.
#
# **(d) Success Metrics (Year 1 Targets):**
# 1.  100% compliance with moratorium; map of high-risk zones published.
# 2.  Task Force convened, initial sector analysis completed.
# 3.  80% of identified migrant arrivals receive coordinated intake/services.
#
# **(e) Key New Data to Collect:**
# **Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.
#
# **(f) Contingency if Policy Fails:**
# If Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**
#
# **Confidence: High** for policy logic; **Low** for precise local cost estimates.
#
# #### **Year 2**
# **(a) Policy Actions & Rationale:**
# 1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.
# 2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.
# 3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.
# 2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.
# 3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Reduces future rescue costs; creates career pathways; adds housing.
# *   *Risks:* Buyouts can be socially disruptive; training may not match job creation; ADUs could increase density in risky areas if not sited carefully.
#
# **(d) Success Metrics (Year 2 Targets):**
# 1.  50 voluntary buyout offers made; 20 accepted.
# 2.  200 scholarships awarded; 90% completion rate for first cohort.
# 3.  100 new ADU permits issued; 2 vacant buildings converted.
#
# **(e) Key New Data to Collect:**
# **Projections of "climate migrant" skill sets and demographics.** *Why:* To align workforce programs with actual human capital entering the city.
#
# **(f) Contingency if Policy Fails:**
# If buyout uptake is <10%, **shift to incentivizing flood-proof retrofits for critical community anchors** (clinics, churches) in same zones.
#
# **Confidence: Medium.** Models exist for these policies, but local uptake is uncertain.
#
# #### **Year 3**
# **(a) Policy Actions & Rationale:**
# 1.  **Begin construction of first phase of a **distributed green-grey infrastructure** system (e.g., wetland restoration, berms, upgraded drainage in a critical watershed). *Rationale:* Provides physical protection, jobs, and ecological benefits.
# 2.  **Pilot a "Community Land Trust" (CLT) in a moderate-risk neighborhood.** *Rationale:* Permanently removes land from speculation, ensuring long-term affordability and community control during redevelopment.
# 3.  **Create a "Public Works Corps"** hiring from scholarship graduates and migrants for resilience projects. *Rationale:* Directly links training to jobs, builds city-owned implementation capacity.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High ($20-100M). **Funding:** Municipal bonds, federal infrastructure grants, state resilience funds.
# 2.  **Cost:** Low ($1M for seed capital). **Funding:** Philanthropy, CDBG funds.
# 3.  **Cost:** Medium ($5M/year for 100 jobs). **Funding:** Stormwater utility fee, general fund.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Tangible risk reduction; stabilizes communities; creates immediate employment.
# *   *Risks:* Infrastructure cost overruns; CLT faces legal hurdles; Public Works Corps could be seen as make-work.
#
# **(d) Success Metrics (Year 3 Targets):**
# 1.  First project breaks ground; 50 local jobs created in construction.
# 2.  CLT established, first 10 properties acquired.
# 3.  Public Works Corps hired, completes first project (e.g., mangrove planting).
#
# **(e) Key New Data to Collect:**
# **Real-time monitoring of groundwater and subsidence** in pilot protection area. *Why:* To validate engineering models and adjust future designs.
#
# **(f) Contingency if Policy Fails:**
# If major grant funding fails, **scale down to a "micro-grid" of neighborhood-scale bioswale and rainwater capture projects** using Public Works Corps.
#
# **Confidence: Medium-Low.** Large infrastructure timelines and costs are highly uncertain.
#
# ---
#
# ### **Year 4-7: Implementation & Scaling (The "Building the New City" Phase)**
#
# **Rationale:** Scale successful pilots, make major capital investments, and harden economic and social systems.
#
# #### **Year 4-5**
# *   **Actions:** Scale green-grey infrastructure city-wide; convert bought-out land to floodwater parks/blueways. Launch municipal broadband to attract remote-work businesses. Expand CLT model.
# *   **Focus:** Spatial transformation and digital economy foundation.
#
# #### **Year 6-7**
# *   **Actions:** Build a secondary water treatment and desalination plant for saltwater intrusion. Establish a city-owned "Green Manufacturing Incubator" on safe, elevated land. Pass a "Right to Shelter" ordinance linked to workforce participation.
# *   **Focus:** Critical lifeline security and advanced economic transition.
#
# **Confidence: Medium.** Direction is clear, but external economic factors dominate success.
#
# ---
#
# ### **Year 8-10: Institutionalization & Legitimacy (The "New Normal" Phase)**
#
# **Rationale:** Embed new systems in law and culture, ensure democratic buy-in, and prepare for the next horizon.
#
# #### **Year 8-10**
# *   **Actions:** Update city charter with a "Resilience Mandate." Issue "Resilience Bonds" tied to specific risk-reduction metrics. Hold participatory budgeting for 20% of resilience revenue. Conduct a city-wide resilience exercise.
# *   **Focus:** Democratic legitimacy, sustainable finance, and continuous adaptation.
#
# **Confidence: Low.** Long-term political continuity is hardest to predict.
#
# ---
#
# ### **(g) Ethical Trade-offs & Resolutions:**
# 1.  **Equity vs. Speed:** Protecting the most vulnerable (equity) can be slower than protecting the most valuable assets (speed). *Resolution:* Prioritized equity in Year 1-3 via data collection and targeted programs, accepting that some economic assets may be temporarily at higher risk.
# 2.  **Local Legacy Residents vs. New Migrants:** Diverting resources to newcomers can seem unfair to struggling existing residents. *Resolution:* Designed programs (Workforce Scholarship, Public Works Corps) to **serve both groups simultaneously**, framing migrants as a needed demographic boost for a transitioning city.
# 3.  **Managed Retreat vs. Community Preservation:** Asking people to leave homes undermines community fabric. *Resolution:* Prioritized **voluntary, pre-disaster buyouts** coupled with **Community Land Trusts** to allow communities to reconstitute in safer areas with cultural continuity.
#
# **Confidence: High.** These are classic adaptation dilemmas; the resolutions are principled and pragmatic.
#
# ### **(h) Early-Warning Indicators & Course Changes:**
# 1.  **Indicator:** Annual SLR acceleration > 7mm/year (vs. current ~4mm). *Threshold:* 2 consecutive years of data.
#     *   **Alternative Action:** Accelerate buyout program from voluntary to **zoned mandatory retreat** for highest-risk areas.
# 2.  **Indicator:** Manufacturing job loss > 5% per year (exceeding 25% decade projection). *Threshold:* 3 consecutive years of loss.
#     *   **Alternative Action:** Pivot Green Manufacturing Incubator to a **direct city-owned enterprise** in a strategic sector (e.g., modular flood-wall manufacturing).
# 3.  **Indicator:** Migrant inflow > 15,000/year (exceeding 100k/15yrs projection). *Threshold:* 2 consecutive years.
#     *   **Alternative Action:** Implement a **"host community" partnership program** with inland cities, funded by the state/feds, to direct and support a coordinated regional response.
#
# **Confidence: Medium.** Indicators are measurable; alternative actions are drastic but necessary.
#
# ### **(i) Scenario Probabilities:**
# *   **Optimistic (Strong cohesion, ample fed/state funding, moderate climate impacts): 20%.**
# *   **Central (Mixed results, moderate funding, climate impacts as projected): 50%.**
# *   **Pessimistic (Political fragmentation, low funding, high climate impacts/migration): 30%.**
# *   **Justification:** The central scenario is most likely based on current trends. The pessimistic scenario has a significant probability due to high national political and climate volatility. The optimistic scenario is least likely given fiscal constraints.
#
# **Confidence: Low.** This is a subjective assessment of deeply uncertain futures.
#
# ### **(j) Key Assumptions & Needed Experts:**
# **Assumptions:**
# 1.  The city retains home-rule authority to implement zoning and tax changes.
# 2.  Some state and federal funding will be available, albeit competitive.
# 3.  Social cohesion can be maintained through transparent process and shared sacrifice.
# 4.  Climate migrants are primarily domestic, from within the same country/region.
#
# **Top Three Outside Experts/Analyses to Commission:**
# 1.  **Actuarial & Municipal Bond Firm:** To stress-test the city's fiscal resilience under different shock scenarios and design credible "Resilience Bonds."
# 2.  **Ethnographic Team:** To conduct deep community listening across all neighborhoods (legacy and new) to understand social fault lines and sources of resilience not visible in quantitative data.
# 3.  **Regional Geotechnical & Hydrological Study:** To model groundwater, subsidence, and compound flooding at a neighborhood scale—the weak point in most SLR projections.
#
# **Confidence: High.** These assumptions are necessary for planning, and these experts address the largest knowledge gaps.
#
# ---
# **Overall Plan Weaknesses:** Cost estimates are highly speculative and location-specific. The plan assumes a baseline level of governmental competence and low-level corruption. It may underestimate the political toxicity of "retreat" and the speed of social tension. Success is **heavily dependent on external funding and national policy context.**
# Competitor: openai/gpt-oss-120b
#
# **Executive Summary**
#
# The 10‑year plan below is a **sequenced, “building‑block” strategy** that tackles the three intertwined threats—sea‑level rise, fiscal erosion, and climate‑migrant influx—while preserving democratic legitimacy and protecting the city’s most vulnerable 30 % of households.  Each year lists three priority actions (A‑C) with their rationale, cost ranges, funding ideas, expected benefits/risks, success metrics, a single critical data‑gap to fill, and a contingency if the primary approach stalls.  The plan is deliberately *iterative*: early actions generate data and institutional capacity that inform later, more ambitious steps.
#
# ---
#
# ## 10‑Year Action Plan (Year‑by‑Year)
#
# | Year | Action | (a) Rationale | (b) Cost (Low‑Central‑High) & Funding | (c) Primary Benefits / Key Risks | (d) Success Metrics (targets) | (e) Critical Data to Collect | (f) Contingency if Action Fails |
# |------|--------|---------------|----------------------------------------|----------------------------------|------------------------------|------------------------------|---------------------------------|
# | **1** | **A1 – Launch a City‑wide Climate‑Resilience Data Hub** (integrated GIS, sensor network, and open‑data portal) | Establishes the evidence base for every subsequent decision; builds transparency → political legitimacy. | $8 M (L) – $12 M (C) – $18 M (H); funded 60 % by state climate‑grant, 30 % municipal bonds, 10 % private‑sector data‑sharing agreements. | **Benefits:** real‑time flood risk maps, tax‑base health dashboard, migration flow tracker. **Risks:** data‑privacy concerns, initial staff learning curve. | 1️⃣ > 90 % of critical infrastructure (roads, utilities) digitized in GIS. <br>2️⃣ Monthly flood‑risk alerts issued to >95 % of households. | **Data Gap:** High‑resolution (≤5 m) elevation & land‑use change model for the next 20 years (why: all adaptation design hinges on accurate exposure). | If grant funding stalls, scale back to a “core” hub covering only flood‑risk layers and seek a phased rollout via a public‑private data‑exchange consortium. |
# | | **B1 – Implement a “Just Transition” Workforce Retraining Program** for workers in the declining manufacturing sector (e.g., green‑tech, coastal‑restoration, health‑services). | Offsets the projected 25 % tax‑base loss, preserves employment, and builds a local climate‑adaptation workforce. | $15 M (L) – $22 M (C) – $30 M (H); funded through a mix of federal Workforce Innovation and Opportunity Act (WIOA) funds, a modest 0.2 % payroll tax on remaining manufacturers, and private‑sector apprenticeship subsidies. | **Benefits:** 70 % of displaced workers placed in new jobs within 2 years; reduces out‑migration. **Risks:** Mismatch between training slots and actual job openings; possible perception of “hand‑outs”. | 1️⃣ ≥ 60 % of targeted workers (≈3,500) enrolled. <br>2️⃣ ≥ 50 % achieve certification and employment in new sector. | **Data Gap:** Real‑time labor‑market demand index for green‑economy occupations within the city (why: to keep training aligned with actual vacancies). | If enrollment lags, partner with nearby community colleges to embed training into existing curricula and offer tuition‑waiver scholarships to boost uptake. |
# | | **C1 – Adopt a “Dynamic Zoning & Building Code” Ordinance** that phases in higher flood‑resilience standards (elevated foundations, flood‑proof utilities) for all new construction and major retrofits in the 0–2 m elevation band. | Early regulatory shift avoids a future “panic‑building” surge, signals seriousness to investors and migrants, and protects the most at‑risk neighborhoods. | $5 M (L) – $9 M (C) – $14 M (H) (administrative, outreach, code‑update staff); funded via a 0.1 % impact fee on new permits and modest reallocation of existing planning budget. | **Benefits:** New builds >30 % more resilient; reduces future emergency repair costs. **Risks:** Higher construction costs may slow private development; possible legal challenges. | 1️⃣ Ordinance passed & 100 % of new permits screened under new code. <br>2️⃣ ≥ 80 % of major retrofits (≥$200k) voluntarily adopt elevated design. | **Data Gap:** Baseline inventory of building elevations and utility depths in the 0‑2 m zone (why: to measure compliance progress). | If political opposition blocks the ordinance, introduce a voluntary “Resilience Certification” label with tax rebates as an interim step. |
# | **2** | **A2 – Deploy a City‑wide Network of Low‑Cost Flood Sensors & Real‑Time Warning System** (integrated with the Data Hub). | Moves from static maps to actionable alerts; saves lives during storm surges and informs evacuation routing for migrants. | $12 M (L) – $18 M (C) – $26 M (H); funded 40 % by FEMA’s Pre‑Disaster Mitigation (PDM) grant, 30 % municipal capital budget, 30 % utility co‑investment (e.g., water & power). | **Benefits:** 30 % reduction in flood‑related injuries; better emergency‑service allocation. **Risks:** Maintenance costs, false alarms eroding trust. | 1️⃣ ≥ 90 % of high‑risk parcels (≈45 k) covered by sensors. <br>2️⃣ Average evacuation lead‑time ≥15 min before inundation. | **Data Gap:** Sensor reliability & false‑positive rate under varying weather conditions (why: to calibrate alert thresholds). | If funding gaps appear, pilot the system in the most vulnerable district first and seek additional private sponsorship for city‑wide roll‑out. |
# | | **B2 – Create a “Climate‑Migrant Integration Hub”** (one‑stop service center offering language classes, legal aid, job‑matching, and temporary shelter). | Addresses the anticipated 100 k inflow, reduces social tension, and channels migrants into the retraining pipeline. | $10 M (L) – $16 M (C) – $23 M (H); funded through HUD’s Community Development Block Grant (CDBG) allocation, a modest 0.05 % sales‑tax increment, and philanthropy. | **Benefits:** Faster labor‑market integration; reduces informal settlements. **Risks:** Perceived competition for services among existing low‑income residents. | 1️⃣ ≥ 70 % of incoming migrants registered within 3 months of arrival. <br>2️⃣ ≥ 40 % placed in training or employment within 6 months. | **Data Gap:** Real‑time demographic profile (age, skill, health) of incoming migrants (why: to tailor services and anticipate demand). | If uptake is low, partner with faith‑based NGOs to co‑locate satellite “pop‑up” hubs in neighborhoods where migrants settle. |
# | | **C2 – Launch a “Coastal Green Infrastructure” Pilot** (living shorelines, mangrove planting, permeable sidewalks) on 2 km of the most exposed waterfront. | Generates immediate flood attenuation, creates jobs for retraining graduates, and demonstrates benefits to the public. | $8 M (L) – $13 M (C) – $20 M (H); funded 50 % by state coastal resilience grant, 25 % municipal capital, 25 % corporate sponsorship (e.g., waterfront developers). | **Benefits:** 0.2 m reduction in projected inundation depth; carbon sequestration. **Risks:** Maintenance burden; potential conflict with commercial dock owners. | 1️⃣ Construction completed by end‑year. <br>2️⃣ Measured wave‑energy reduction ≥15 % at pilot site. | **Data Gap:** Pre‑construction baseline of wave height and shoreline erosion rates (why: to quantify impact). | If construction stalls, shift to “modular floating wetlands” that can be installed faster and with less permitting. |
# | **3** | **A3 – Publish an Annual “Resilience Scorecard”** (city‑wide index of flood‑risk, economic health, migrant integration). | Keeps the plan transparent, holds agencies accountable, and provides a political narrative of progress. | $2 M (L) – $3 M (C) – $5 M (H); funded from the Data Hub operating budget and a 0.02 % property‑tax levy earmarked for reporting. | **Benefits:** Improves public trust; informs investors. **Risks:** Scorecard may be politicized if targets missed. | 1️⃣ Scorecard released by Q2 each year. <br>2️⃣ Public satisfaction with city’s climate response ↑ 10 % (survey). | **Data Gap:** Year‑over‑year public perception data on climate‑policy (why: to gauge legitimacy). | If political push‑back occurs, transition to a “dashboard” format hosted on the city website with less narrative framing. |
# | | **B3 – Expand “Just Transition” to a Full‑Scale Green‑Jobs Guarantee** (up to 5 k jobs in renewable energy, coastal restoration, health‑care, and education). | Scales up the workforce pivot before the manufacturing tax base collapses further; provides stable employment for migrants and locals. | $35 M (L) – $48 M (C) – $65 M (H); funded through a mix of federal Inflation Reduction Act (IRA) clean‑energy credits, municipal green bond issuance, and a 0.3 % “climate‑recovery” sales tax. | **Benefits:** Offsets up to 40 % of projected tax‑base loss; reduces poverty. **Risks:** Inflationary pressure on wages; risk of “boom‑bust” if projects finish early. | 1️⃣ ≥ 4 000 new green jobs created. <br>2️⃣ Unemployment rate ≤5 % city‑wide. | **Data Gap:** Real‑time wage‑inflation data for green‑sector jobs (why: to keep the guarantee fiscally sustainable). | If funding shortfalls appear, prioritize “high‑impact” projects (e.g., solar farms on vacant industrial sites) and defer lower‑priority hires. |
# | | **C3 – Adopt a “Managed Retreat” Zoning Overlay** for the 0‑0.5 m elevation zone (≈15 % of the city’s land, home to ~180 k residents). | Begins the hard‑choice of pulling back from the most exposed area before catastrophic loss; integrates with relocation assistance. | $20 M (L) – $30 M (C) – $45 M (H); funded 40 % by federal Hazard Mitigation Grant Program (HMGP), 30 % municipal “relocation reserve” (seeded by a 0.1 % property‑tax surcharge), 30 % private developer contributions (in‑exchange for higher‑density rights elsewhere). | **Benefits:** Reduces future exposure of >150 k people; frees land for flood‑plain restoration. **Risks:** Community opposition, legal challenges, displacement trauma. | 1️⃣ Overlay adopted and legal challenge resolved. <br>2️⃣ ≥ 30 % of at‑risk households (≈54 k) signed voluntary buy‑out agreements. | **Data Gap:** Household‑level risk‑acceptance survey (why: to design equitable buy‑out offers). | If buy‑outs stall, implement “transfer‑of‑development‑rights” (TDR) allowing owners to build in safer zones while the city acquires their flood‑prone parcels. |
# | **4** | **A4 – Upgrade Critical Utilities to “Floating” or “Elevated” Designs** (water treatment, power substations, wastewater). | Protects essential services from inundation, preventing city‑wide outages that would cripple the economy and jeopardize migrant reception. | $50 M (L) – $80 M (C) – $
# Competitor: llama3.2
#
# I can provide a general outline of a 10-year action plan for the coastal city facing the described challenges. Please note that this is a hypothetical plan, and actual policies may vary depending on the city's specific context and priorities.
#
# **Year 1:**
#
# 1. **Policy Actions:**
# 	* a) Implement a comprehensive sea-level rise adaptation plan, including infrastructure upgrades, flood-resistant construction codes, and green infrastructure investments. (Rationale: Immediate action to protect existing infrastructure and residents)
# 	* b) Launch a manufacturing tax reform package, aiming to rebalance tax incentives to favor more resilient and adaptable industries. (Rationale: Address decline in tax base, promote economic diversification)
# 	* c) Establish a Climate Migrant Integration Program, focusing on language training, education, and social assistance. (Rationale: Support vulnerable residents, promote social cohesion)
# 2. *Ballpark Estimated Costs:* Low: $10M; Central: $50M; High: $100M (Funding Mechanisms: General Fund, Public-Private Partnerships)
# 3. *Expected Primary Benefits:* Reduced sea-level rise impacts; diversified economy; increased social cohesion. *Key Risks or Negative Externalities:* Inefficient allocation of resources; increased administrative burdens.
# 4. *Measurable Success Metrics:* Sea-level rise vulnerability reduction (using adapted infrastructure); Manufacturing tax reform package adoption rate; Climate Migrant Integration Program participant enrollment.
# 5. *Most Important New Data to Collect:* Sea-level rise prediction accuracy and its associated uncertainty.
# 6. *Contingency Action:* Emergency funding for sea-level rise flood mitigation measures if primary policy fails.
#
# **Year 2-10:**
#
# Policy Actions, Funding, and Success Metrics are tailored to each subsequent year, reflecting the progression and escalation of the challenges. The primary goal, however, remains protection, sustainability, and democratic legitimacy.
#
# **Ethical Trade-offs:**
#
# 1. Balancing economic recovery and climate resilience.
# 2. Prioritizing vulnerable population adaptation, vs. protecting broader community interests.
# 3. Weighing short-term infrastructure upgrades against long-term environmental costs.
#
# **Early-Warning Indicators and Contingency Actions:**
#
# 1. **Sea-level Rise Impacts Exceed Initial Projections:** (Threshold Value: > 2m sea-level rise by 2025); Alternative Action: Deploy temporary sea-level rise shelters for most affected residents and accelerate infrastructure upgrade schedule.
# 2. **Manufacturing Tax Reform Package Failure:** (Threshold Value: < 20% adoption rate within 2 years); Alternative Action: Engage private sector for co-investment and collaboration to adapt to change.
# 3. **Climate Migrant Influx Exceeds Initial Estimates:** (Threshold Value: more than 50% of expected influx); Alternative Action: Implement a temporary temporary housing solution, with focus on sustainable settlement integration.
#
# **Uncertainty Quantification:**
#
# 1. Optimistic Scenario: Average sea-level rise reduction through combined policy and technological progress; strong manufacturing tax reform adoption; high migrant integration rate. (Probability: 20%)
# 2. Central Scenario: Moderate sea-level rise impact reduction; partial manufacturing tax reform success; adequate but cautious migrant integration rate. (Probability: 60%)
# 3. Pessimistic Scenario: High sea-level rise impact; failed manufacturing tax reform; limited migrant integration. (Probability: 20%)
#
# *Key Assumptions:*
# 1. Government will allocate funds for adaptation efforts.
# 2. Manufacturing industry will collaborate with city officials.
# 3. Public is aware and supportive of the plan.
#
# *Complimentary Research and Expert Input:* To validate this approach, commission an expert analysis on:
#
# 1. Sea-level rise predictive models.
# 2. The impacts of manufacturing tax reform on the city's economy.
# 3. Effective integration strategies for climate migrants.
#
# Please note that while the hypothetical plan provides a structured approach, it must be continually reviewed and updated as new information becomes available and the city's situation evolves.

# %%
answers
# Out:
# ['**Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.\n\n---\n\n### **10-Year Action Plan: Resilience, Transition, & Integration**\n\n**Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.\n\n---\n\n### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**\n\n**Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.\n\n#### **Year 1**\n**(a) Policy Actions & Rationale:**\n1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.\n2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.\n3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.\n\n**(b) Estimated Costs & Funding:**\n1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.\n2.  **Cost:** Low ($500k). **Funding:** General fund allocation.\n3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.\n\n**(c) Benefits & Risks:**\n*   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.\n*   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.\n\n**(d) Success Metrics (Year 1 Targets):**\n1.  100% compliance with moratorium; map of high-risk zones published.\n2.  Task Force convened, initial sector analysis completed.\n3.  80% of identified migrant arrivals receive coordinated intake/services.\n\n**(e) Key New Data to Collect:**\n**Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.\n\n**(f) Contingency if Policy Fails:**\nIf Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**\n\n**Confidence: High** for policy logic; **Low** for precise local cost estimates.\n\n#### **Year 2**\n**(a) Policy Actions & Rationale:**\n1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.\n2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.\n3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.\n\n**(b) Estimated Costs & Funding:**\n1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.\n2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.\n3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.\n\n**(c ...
#  '**Executive Summary**\n\nThe 10‑year plan below is a **sequenced, “building‑block” strategy** that tackles the three intertwined threats—sea‑level rise, fiscal erosion, and climate‑migrant influx—while preserving democratic legitimacy and protecting the city’s most vulnerable 30\u202f% of households.  Each year lists three priority actions (A‑C) with their rationale, cost ranges, funding ideas, expected benefits/risks, success metrics, a single critical data‑gap to fill, and a contingency if the primary approach stalls.  The plan is deliberately *iterative*: early actions generate data and institutional capacity that inform later, more ambitious steps.\n\n---\n\n## 10‑Year Action Plan (Year‑by‑Year)\n\n| Year | Action | (a) Rationale | (b) Cost (Low‑Central‑High) & Funding | (c) Primary Benefits / Key Risks | (d) Success Metrics (targets) | (e) Critical Data to Collect | (f) Contingency if Action Fails |\n|------|--------|---------------|----------------------------------------|----------------------------------|------------------------------|------------------------------|---------------------------------|\n| **1** | **A1 – Launch a City‑wide Climate‑Resilience Data Hub** (integrated GIS, sensor network, and open‑data portal) | Establishes the evidence base for every subsequent decision; builds transparency → political legitimacy. | $8\u202fM\u202f(L) – $12\u202fM\u202f(C) – $18\u202fM\u202f(H); funded 60\u202f% by state climate‑grant, 30\u202f% municipal bonds, 10\u202f% private‑sector data‑sharing agreements. | **Benefits:** real‑time flood risk maps, tax‑base health dashboard, migration flow tracker. **Risks:** data‑privacy concerns, initial staff learning curve. | 1️⃣\u202f>\u202f90\u202f% of critical infrastructure (roads, utilities) digitized in GIS. <br>2️⃣\u202fMonthly flood‑risk alerts issued to >95\u202f% of households. | **Data Gap:** High‑resolution (≤5\u202fm) elevation & land‑use change model for the next 20\u202fyears (why: all adaptation design hinges on accurate exposure). | If grant funding stalls, scale back to a “core” hub covering only flood‑risk layers and seek a phased rollout via a public‑private data‑exchange consortium. |\n| | **B1 – Implement a “Just Transition” Workforce Retraining Program** for workers in the declining manufacturing sector (e.g., green‑tech, coastal‑restoration, health‑services). | Offsets the projected 25\u202f% tax‑base loss, preserves employment, and builds a local climate‑adaptation workforce. | $15\u202fM\u202f(L) – $22\u202fM\u202f(C) – $30\u202fM\u202f(H); funded through a mix of federal Workforce Innovation and Opportunity Act (WIOA) funds, a modest 0.2\u202f% payroll tax on remaining manufacturers, and private‑sector apprenticeship subsidies. | **Benefits:** 70\u202f% of displaced workers placed in new jobs within 2\u202fyears; reduces out‑migration. **Risks:** Mismatch between training slots and actual job openings; possible perception of “hand‑outs”. | 1️⃣\u202f≥\u202f60\u202f% of targeted workers (≈3,500) enrolled. <br>2️⃣\u202f≥\u202f50\u202f% achieve certification and employment in new sector. | **Data Gap:** Real‑time labor‑market demand index for green‑economy occupations within the city (why: to keep training aligned with actual vacancies). | If enrollment lags, partner with nearby community colleges to embed training into existing curricula and offer tuition‑waiver scholarships to boost uptake. |\n| | **C1 – Adopt a “Dynamic Zoning & Building Code” Ordinance** that phases in higher flood‑resilience standards (elevated foundations, flood‑proof utilities) for all new construction and major retrofits in the 0–2\u202fm elevation band. | Early regulatory shift avoids a future “panic‑building” surge, signals seriousness to investors and migrants, and protects the most at‑risk neighborhoods. | $5\u202fM\u202f(L) – $9\u202fM\u202f(C) – $14\u202fM\u202f(H) (administrative, outreach, code‑update staff); funded via a 0.1\u202f% impact fee on new permits and modest realloc ...
#  "I can provide a general outline of a 10-year action plan for the coastal city facing the described challenges. Please note that this is a hypothetical plan, and actual policies may vary depending on the city's specific context and priorities.\n\n**Year 1:**\n\n1. **Policy Actions:**\n\t* a) Implement a comprehensive sea-level rise adaptation plan, including infrastructure upgrades, flood-resistant construction codes, and green infrastructure investments. (Rationale: Immediate action to protect existing infrastructure and residents)\n\t* b) Launch a manufacturing tax reform package, aiming to rebalance tax incentives to favor more resilient and adaptable industries. (Rationale: Address decline in tax base, promote economic diversification)\n\t* c) Establish a Climate Migrant Integration Program, focusing on language training, education, and social assistance. (Rationale: Support vulnerable residents, promote social cohesion)\n2. *Ballpark Estimated Costs:* Low: $10M; Central: $50M; High: $100M (Funding Mechanisms: General Fund, Public-Private Partnerships)\n3. *Expected Primary Benefits:* Reduced sea-level rise impacts; diversified economy; increased social cohesion. *Key Risks or Negative Externalities:* Inefficient allocation of resources; increased administrative burdens.\n4. *Measurable Success Metrics:* Sea-level rise vulnerability reduction (using adapted infrastructure); Manufacturing tax reform package adoption rate; Climate Migrant Integration Program participant enrollment.\n5. *Most Important New Data to Collect:* Sea-level rise prediction accuracy and its associated uncertainty.\n6. *Contingency Action:* Emergency funding for sea-level rise flood mitigation measures if primary policy fails.\n\n**Year 2-10:**\n\nPolicy Actions, Funding, and Success Metrics are tailored to each subsequent year, reflecting the progression and escalation of the challenges. The primary goal, however, remains protection, sustainability, and democratic legitimacy.\n\n**Ethical Trade-offs:**\n\n1. Balancing economic recovery and climate resilience.\n2. Prioritizing vulnerable population adaptation, vs. protecting broader community interests.\n3. Weighing short-term infrastructure upgrades against long-term environmental costs.\n\n**Early-Warning Indicators and Contingency Actions:**\n\n1. **Sea-level Rise Impacts Exceed Initial Projections:** (Threshold Value: > 2m sea-level rise by 2025); Alternative Action: Deploy temporary sea-level rise shelters for most affected residents and accelerate infrastructure upgrade schedule.\n2. **Manufacturing Tax Reform Package Failure:** (Threshold Value: < 20% adoption rate within 2 years); Alternative Action: Engage private sector for co-investment and collaboration to adapt to change.\n3. **Climate Migrant Influx Exceeds Initial Estimates:** (Threshold Value: more than 50% of expected influx); Alternative Action: Implement a temporary temporary housing solution, with focus on sustainable settlement integration.\n\n**Uncertainty Quantification:**\n\n1. Optimistic Scenario: Average sea-level rise reduction through combined policy and technological progress; strong manufacturing tax reform adoption; high migrant integration rate. (Probability: 20%)\n2. Central Scenario: Moderate sea-level rise impact reduction; partial manufacturing tax reform success; adequate but cautious migrant integration rate. (Probability: 60%)\n3. Pessimistic Scenario: High sea-level rise impact; failed manufacturing tax reform; limited migrant integration. (Probability: 20%)\n\n*Key Assumptions:* \n1. Government will allocate funds for adaptation efforts.\n2. Manufacturing industry will collaborate with city officials.\n3. Public is aware and supportive of the plan.\n\n*Complimentary Research and Expert Input:* To validate this approach, commission an expert analysis on:\n\n1. Sea-level rise predictive models.\n2. The impacts of manufacturing tax reform on the city's economy.\n3. Effective integration strategies for climate mig ...

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# **Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.
#
# ---
#
# ### **10-Year Action Plan: Resilience, Transition, & Integration**
#
# **Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.
#
# ---
#
# ### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**
#
# **Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.
#
# #### **Year 1**
# **(a) Policy Actions & Rationale:**
# 1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.
# 2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.
# 3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.
# 2.  **Cost:** Low ($500k). **Funding:** General fund allocation.
# 3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.
# *   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.
#
# **(d) Success Metrics (Year 1 Targets):**
# 1.  100% compliance with moratorium; map of high-risk zones published.
# 2.  Task Force convened, initial sector analysis completed.
# 3.  80% of identified migrant arrivals receive coordinated intake/services.
#
# **(e) Key New Data to Collect:**
# **Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.
#
# **(f) Contingency if Policy Fails:**
# If Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**
#
# **Confidence: High** for policy logic; **Low** for precise local cost estimates.
#
# #### **Year 2**
# **(a) Policy Actions & Rationale:**
# 1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.
# 2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.
# 3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.
# 2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.
# 3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Reduces future rescue costs; creates career pathways; adds housing.
# *   *Risks:* Buyouts can be socially disruptive; training may not match job creation; ADUs could increase density in risky areas if not sited carefully.
#
# **(d) Success Metrics (Year 2 Targets):**
# 1.  50 voluntary buyout offers made; 20 accepted.
# 2.  200 scholarships awarded; 90% completion rate for first cohort.
# 3.  100 new ADU permits issued; 2 vacant buildings converted.
#
# **(e) Key New Data to Collect:**
# **Projections of "climate migrant" skill sets and demographics.** *Why:* To align workforce programs with actual human capital entering the city.
#
# **(f) Contingency if Policy Fails:**
# If buyout uptake is <10%, **shift to incentivizing flood-proof retrofits for critical community anchors** (clinics, churches) in same zones.
#
# **Confidence: Medium.** Models exist for these policies, but local uptake is uncertain.
#
# #### **Year 3**
# **(a) Policy Actions & Rationale:**
# 1.  **Begin construction of first phase of a **distributed green-grey infrastructure** system (e.g., wetland restoration, berms, upgraded drainage in a critical watershed). *Rationale:* Provides physical protection, jobs, and ecological benefits.
# 2.  **Pilot a "Community Land Trust" (CLT) in a moderate-risk neighborhood.** *Rationale:* Permanently removes land from speculation, ensuring long-term affordability and community control during redevelopment.
# 3.  **Create a "Public Works Corps"** hiring from scholarship graduates and migrants for resilience projects. *Rationale:* Directly links training to jobs, builds city-owned implementation capacity.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High ($20-100M). **Funding:** Municipal bonds, federal infrastructure grants, state resilience funds.
# 2.  **Cost:** Low ($1M for seed capital). **Funding:** Philanthropy, CDBG funds.
# 3.  **Cost:** Medium ($5M/year for 100 jobs). **Funding:** Stormwater utility fee, general fund.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Tangible risk reduction; stabilizes communities; creates immediate employment.
# *   *Risks:* Infrastructure cost overruns; CLT faces legal hurdles; Public Works Corps could be seen as make-work.
#
# **(d) Success Metrics (Year 3 Targets):**
# 1.  First project breaks ground; 50 local jobs created in construction.
# 2.  CLT established, first 10 properties acquired.
# 3.  Public Works Corps hired, completes first project (e.g., mangrove planting).
#
# **(e) Key New Data to Collect:**
# **Real-time monitoring of groundwater and subsidence** in pilot protection area. *Why:* To validate engineering models and adjust future designs.
#
# **(f) Contingency if Policy Fails:**
# If major grant funding fails, **scale down to a "micro-grid" of neighborhood-scale bioswale and rainwater capture projects** using Public Works Corps.
#
# **Confidence: Medium-Low.** Large infrastructure timelines and costs are highly uncertain.
#
# ---
#
# ### **Year 4-7: Implementation & Scaling (The "Building the New City" Phase)**
#
# **Rationale:** Scale successful pilots, make major capital investments, and harden economic and social systems.
#
# #### **Year 4-5**
# *   **Actions:** Scale green-grey infrastructure city-wide; convert bought-out land to floodwater parks/blueways. Launch municipal broadband to attract remote-work businesses. Expand CLT model.
# *   **Focus:** Spatial transformation and digital economy foundation.
#
# #### **Year 6-7**
# *   **Actions:** Build a secondary water treatment and desalination plant for saltwater intrusion. Establish a city-owned "Green Manufacturing Incubator" on safe, elevated land. Pass a "Right to Shelter" ordinance linked to workforce participation.
# *   **Focus:** Critical lifeline security and advanced economic transition.
#
# **Confidence: Medium.** Direction is clear, but external economic factors dominate success.
#
# ---
#
# ### **Year 8-10: Institutionalization & Legitimacy (The "New Normal" Phase)**
#
# **Rationale:** Embed new systems in law and culture, ensure democratic buy-in, and prepare for the next horizon.
#
# #### **Year 8-10**
# *   **Actions:** Update city charter with a "Resilience Mandate." Issue "Resilience Bonds" tied to specific risk-reduction metrics. Hold participatory budgeting for 20% of resilience revenue. Conduct a city-wide resilience exercise.
# *   **Focus:** Democratic legitimacy, sustainable finance, and continuous adaptation.
#
# **Confidence: Low.** Long-term political continuity is hardest to predict.
#
# ---
#
# ### **(g) Ethical Trade-offs & Resolutions:**
# 1.  **Equity vs. Speed:** Protecting the most vulnerable (equity) can be slower than protecting the most valuable assets (speed). *Resolution:* Prioritized equity in Year 1-3 via data collection and targeted programs, accepting that some economic assets may be temporarily at higher risk.
# 2.  **Local Legacy Residents vs. New Migrants:** Diverting resources to newcomers can seem unfair to struggling existing residents. *Resolution:* Designed programs (Workforce Scholarship, Public Works Corps) to **serve both groups simultaneously**, framing migrants as a needed demographic boost for a transitioning city.
# 3.  **Managed Retreat vs. Community Preservation:** Asking people to leave homes undermines community fabric. *Resolution:* Prioritized **voluntary, pre-disaster buyouts** coupled with **Community Land Trusts** to allow communities to reconstitute in safer areas with cultural continuity.
#
# **Confidence: High.** These are classic adaptation dilemmas; the resolutions are principled and pragmatic.
#
# ### **(h) Early-Warning Indicators & Course Changes:**
# 1.  **Indicator:** Annual SLR acceleration > 7mm/year (vs. current ~4mm). *Threshold:* 2 consecutive years of data.
#     *   **Alternative Action:** Accelerate buyout program from voluntary to **zoned mandatory retreat** for highest-risk areas.
# 2.  **Indicator:** Manufacturing job loss > 5% per year (exceeding 25% decade projection). *Threshold:* 3 consecutive years of loss.
#     *   **Alternative Action:** Pivot Green Manufacturing Incubator to a **direct city-owned enterprise** in a strategic sector (e.g., modular flood-wall manufacturing).
# 3.  **Indicator:** Migrant inflow > 15,000/year (exceeding 100k/15yrs projection). *Threshold:* 2 consecutive years.
#     *   **Alternative Action:** Implement a **"host community" partnership program** with inland cities, funded by the state/feds, to direct and support a coordinated regional response.
#
# **Confidence: Medium.** Indicators are measurable; alternative actions are drastic but necessary.
#
# ### **(i) Scenario Probabilities:**
# *   **Optimistic (Strong cohesion, ample fed/state funding, moderate climate impacts): 20%.**
# *   **Central (Mixed results, moderate funding, climate impacts as projected): 50%.**
# *   **Pessimistic (Political fragmentation, low funding, high climate impacts/migration): 30%.**
# *   **Justification:** The central scenario is most likely based on current trends. The pessimistic scenario has a significant probability due to high national political and climate volatility. The optimistic scenario is least likely given fiscal constraints.
#
# **Confidence: Low.** This is a subjective assessment of deeply uncertain futures.
#
# ### **(j) Key Assumptions & Needed Experts:**
# **Assumptions:**
# 1.  The city retains home-rule authority to implement zoning and tax changes.
# 2.  Some state and federal funding will be available, albeit competitive.
# 3.  Social cohesion can be maintained through transparent process and shared sacrifice.
# 4.  Climate migrants are primarily domestic, from within the same country/region.
#
# **Top Three Outside Experts/Analyses to Commission:**
# 1.  **Actuarial & Municipal Bond Firm:** To stress-test the city's fiscal resilience under different shock scenarios and design credible "Resilience Bonds."
# 2.  **Ethnographic Team:** To conduct deep community listening across all neighborhoods (legacy and new) to understand social fault lines and sources of resilience not visible in quantitative data.
# 3.  **Regional Geotechnical & Hydrological Study:** To model groundwater, subsidence, and compound flooding at a neighborhood scale—the weak point in most SLR projections.
#
# **Confidence: High.** These assumptions are necessary for planning, and these experts address the largest knowledge gaps.
#
# ---
# **Overall Plan Weaknesses:** Cost estimates are highly speculative and location-specific. The plan assumes a baseline level of governmental competence and low-level corruption. It may underestimate the political toxicity of "retreat" and the speed of social tension. Success is **heavily dependent on external funding and national policy context.**
#
# # Response from competitor 2
#
# **Executive Summary**
#
# The 10‑year plan below is a **sequenced, “building‑block” strategy** that tackles the three intertwined threats—sea‑level rise, fiscal erosion, and climate‑migrant influx—while preserving democratic legitimacy and protecting the city’s most vulnerable 30 % of households.  Each year lists three priority actions (A‑C) with their rationale, cost ranges, funding ideas, expected benefits/risks, success metrics, a single critical data‑gap to fill, and a contingency if the primary approach stalls.  The plan is deliberately *iterative*: early actions generate data and institutional capacity that inform later, more ambitious steps.
#
# ---
#
# ## 10‑Year Action Plan (Year‑by‑Year)
#
# | Year | Action | (a) Rationale | (b) Cost (Low‑Central‑High) & Funding | (c) Primary Benefits / Key Risks | (d) Success Metrics (targets) | (e) Critical Data to Collect | (f) Contingency if Action Fails |
# |------|--------|---------------|----------------------------------------|----------------------------------|------------------------------|------------------------------|---------------------------------|
# | **1** | **A1 – Launch a City‑wide Climate‑Resilience Data Hub** (integrated GIS, sensor network, and open‑data portal) | Establishes the evidence base for every subsequent decision; builds transparency → political legitimacy. | $8 M (L) – $12 M (C) – $18 M (H); funded 60 % by state climate‑grant, 30 % municipal bonds, 10 % private‑sector data‑sharing agreements. | **Benefits:** real‑time flood risk maps, tax‑base health dashboard, migration flow tracker. **Risks:** data‑privacy concerns, initial staff learning curve. | 1️⃣ > 90 % of critical infrastructure (roads, utilities) digitized in GIS. <br>2️⃣ Monthly flood‑risk alerts issued to >95 % of households. | **Data Gap:** High‑resolution (≤5 m) elevation & land‑use change model for the next 20 years (why: all adaptation design hinges on accurate exposure). | If grant funding stalls, scale back to a “core” hub covering only flood‑risk layers and seek a phased rollout via a public‑private data‑exchange consortium. |
# | | **B1 – Implement a “Just Transition” Workforce Retraining Program** for workers in the declining manufacturing sector (e.g., green‑tech, coastal‑restoration, health‑services). | Offsets the projected 25 % tax‑base loss, preserves employment, and builds a local climate‑adaptation workforce. | $15 M (L) – $22 M (C) – $30 M (H); funded through a mix of federal Workforce Innovation and Opportunity Act (WIOA) funds, a modest 0.2 % payroll tax on remaining manufacturers, and private‑sector apprenticeship subsidies. | **Benefits:** 70 % of displaced workers placed in new jobs within 2 years; reduces out‑migration. **Risks:** Mismatch between training slots and actual job openings; possible perception of “hand‑outs”. | 1️⃣ ≥ 60 % of targeted workers (≈3,500) enrolled. <br>2️⃣ ≥ 50 % achieve certification and employment in new sector. | **Data Gap:** Real‑time labor‑market demand index for green‑economy occupations within the city (why: to keep training aligned with actual vacancies). | If enrollment lags, partner with nearby community colleges to embed training into existing curricula and offer tuition‑waiver scholarships to boost uptake. |
# | | **C1 – Adopt a “Dynamic Zoning & Building Code” Ordinance** that phases in higher flood‑resilience standards (elevated foundations, flood‑proof utilities) for all new construction and major retrofits in the 0–2 m elevation band. | Early regulatory shift avoids a future “panic‑building” surge, signals seriousness to investors and migrants, and protects the most at‑risk neighborhoods. | $5 M (L) – $9 M (C) – $14 M (H) (administrative, outreach, code‑update staff); funded via a 0.1 % impact fee on new permits and modest reallocation of existing planning budget. | **Benefits:** New builds >30 % more resilient; reduces future emergency repair costs. **Risks:** Higher construction costs may slow private development; possible legal challenges. | 1️⃣ Ordinance passed & 100 % of new permits screened under new code. <br>2️⃣ ≥ 80 % of major retrofits (≥$200k) voluntarily adopt elevated design. | **Data Gap:** Baseline inventory of building elevations and utility depths in the 0‑2 m zone (why: to measure compliance progress). | If political opposition blocks the ordinance, introduce a voluntary “Resilience Certification” label with tax rebates as an interim step. |
# | **2** | **A2 – Deploy a City‑wide Network of Low‑Cost Flood Sensors & Real‑Time Warning System** (integrated with the Data Hub). | Moves from static maps to actionable alerts; saves lives during storm surges and informs evacuation routing for migrants. | $12 M (L) – $18 M (C) – $26 M (H); funded 40 % by FEMA’s Pre‑Disaster Mitigation (PDM) grant, 30 % municipal capital budget, 30 % utility co‑investment (e.g., water & power). | **Benefits:** 30 % reduction in flood‑related injuries; better emergency‑service allocation. **Risks:** Maintenance costs, false alarms eroding trust. | 1️⃣ ≥ 90 % of high‑risk parcels (≈45 k) covered by sensors. <br>2️⃣ Average evacuation lead‑time ≥15 min before inundation. | **Data Gap:** Sensor reliability & false‑positive rate under varying weather conditions (why: to calibrate alert thresholds). | If funding gaps appear, pilot the system in the most vulnerable district first and seek additional private sponsorship for city‑wide roll‑out. |
# | | **B2 – Create a “Climate‑Migrant Integration Hub”** (one‑stop service center offering language classes, legal aid, job‑matching, and temporary shelter). | Addresses the anticipated 100 k inflow, reduces social tension, and channels migrants into the retraining pipeline. | $10 M (L) – $16 M (C) – $23 M (H); funded through HUD’s Community Development Block Grant (CDBG) allocation, a modest 0.05 % sales‑tax increment, and philanthropy. | **Benefits:** Faster labor‑market integration; reduces informal settlements. **Risks:** Perceived competition for services among existing low‑income residents. | 1️⃣ ≥ 70 % of incoming migrants registered within 3 months of arrival. <br>2️⃣ ≥ 40 % placed in training or employment within 6 months. | **Data Gap:** Real‑time demographic profile (age, skill, health) of incoming migrants (why: to tailor services and anticipate demand). | If uptake is low, partner with faith‑based NGOs to co‑locate satellite “pop‑up” hubs in neighborhoods where migrants settle. |
# | | **C2 – Launch a “Coastal Green Infrastructure” Pilot** (living shorelines, mangrove planting, permeable sidewalks) on 2 km of the most exposed waterfront. | Generates immediate flood attenuation, creates jobs for retraining graduates, and demonstrates benefits to the public. | $8 M (L) – $13 M (C) – $20 M (H); funded 50 % by state coastal resilience grant, 25 % municipal capital, 25 % corporate sponsorship (e.g., waterfront developers). | **Benefits:** 0.2 m reduction in projected inundation depth; carbon sequestration. **Risks:** Maintenance burden; potential conflict with commercial dock owners. | 1️⃣ Construction completed by end‑year. <br>2️⃣ Measured wave‑energy reduction ≥15 % at pilot site. | **Data Gap:** Pre‑construction baseline of wave height and shoreline erosion rates (why: to quantify impact). | If construction stalls, shift to “modular floating wetlands” that can be installed faster and with less permitting. |
# | **3** | **A3 – Publish an Annual “Resilience Scorecard”** (city‑wide index of flood‑risk, economic health, migrant integration). | Keeps the plan transparent, holds agencies accountable, and provides a political narrative of progress. | $2 M (L) – $3 M (C) – $5 M (H); funded from the Data Hub operating budget and a 0.02 % property‑tax levy earmarked for reporting. | **Benefits:** Improves public trust; informs investors. **Risks:** Scorecard may be politicized if targets missed. | 1️⃣ Scorecard released by Q2 each year. <br>2️⃣ Public satisfaction with city’s climate response ↑ 10 % (survey). | **Data Gap:** Year‑over‑year public perception data on climate‑policy (why: to gauge legitimacy). | If political push‑back occurs, transition to a “dashboard” format hosted on the city website with less narrative framing. |
# | | **B3 – Expand “Just Transition” to a Full‑Scale Green‑Jobs Guarantee** (up to 5 k jobs in renewable energy, coastal restoration, health‑care, and education). | Scales up the workforce pivot before the manufacturing tax base collapses further; provides stable employment for migrants and locals. | $35 M (L) – $48 M (C) – $65 M (H); funded through a mix of federal Inflation Reduction Act (IRA) clean‑energy credits, municipal green bond issuance, and a 0.3 % “climate‑recovery” sales tax. | **Benefits:** Offsets up to 40 % of projected tax‑base loss; reduces poverty. **Risks:** Inflationary pressure on wages; risk of “boom‑bust” if projects finish early. | 1️⃣ ≥ 4 000 new green jobs created. <br>2️⃣ Unemployment rate ≤5 % city‑wide. | **Data Gap:** Real‑time wage‑inflation data for green‑sector jobs (why: to keep the guarantee fiscally sustainable). | If funding shortfalls appear, prioritize “high‑impact” projects (e.g., solar farms on vacant industrial sites) and defer lower‑priority hires. |
# | | **C3 – Adopt a “Managed Retreat” Zoning Overlay** for the 0‑0.5 m elevation zone (≈15 % of the city’s land, home to ~180 k residents). | Begins the hard‑choice of pulling back from the most exposed area before catastrophic loss; integrates with relocation assistance. | $20 M (L) – $30 M (C) – $45 M (H); funded 40 % by federal Hazard Mitigation Grant Program (HMGP), 30 % municipal “relocation reserve” (seeded by a 0.1 % property‑tax surcharge), 30 % private developer contributions (in‑exchange for higher‑density rights elsewhere). | **Benefits:** Reduces future exposure of >150 k people; frees land for flood‑plain restoration. **Risks:** Community opposition, legal challenges, displacement trauma. | 1️⃣ Overlay adopted and legal challenge resolved. <br>2️⃣ ≥ 30 % of at‑risk households (≈54 k) signed voluntary buy‑out agreements. | **Data Gap:** Household‑level risk‑acceptance survey (why: to design equitable buy‑out offers). | If buy‑outs stall, implement “transfer‑of‑development‑rights” (TDR) allowing owners to build in safer zones while the city acquires their flood‑prone parcels. |
# | **4** | **A4 – Upgrade Critical Utilities to “Floating” or “Elevated” Designs** (water treatment, power substations, wastewater). | Protects essential services from inundation, preventing city‑wide outages that would cripple the economy and jeopardize migrant reception. | $50 M (L) – $80 M (C) – $
#
# # Response from competitor 3
#
# I can provide a general outline of a 10-year action plan for the coastal city facing the described challenges. Please note that this is a hypothetical plan, and actual policies may vary depending on the city's specific context and priorities.
#
# **Year 1:**
#
# 1. **Policy Actions:**
# 	* a) Implement a comprehensive sea-level rise adaptation plan, including infrastructure upgrades, flood-resistant construction codes, and green infrastructure investments. (Rationale: Immediate action to protect existing infrastructure and residents)
# 	* b) Launch a manufacturing tax reform package, aiming to rebalance tax incentives to favor more resilient and adaptable industries. (Rationale: Address decline in tax base, promote economic diversification)
# 	* c) Establish a Climate Migrant Integration Program, focusing on language training, education, and social assistance. (Rationale: Support vulnerable residents, promote social cohesion)
# 2. *Ballpark Estimated Costs:* Low: $10M; Central: $50M; High: $100M (Funding Mechanisms: General Fund, Public-Private Partnerships)
# 3. *Expected Primary Benefits:* Reduced sea-level rise impacts; diversified economy; increased social cohesion. *Key Risks or Negative Externalities:* Inefficient allocation of resources; increased administrative burdens.
# 4. *Measurable Success Metrics:* Sea-level rise vulnerability reduction (using adapted infrastructure); Manufacturing tax reform package adoption rate; Climate Migrant Integration Program participant enrollment.
# 5. *Most Important New Data to Collect:* Sea-level rise prediction accuracy and its associated uncertainty.
# 6. *Contingency Action:* Emergency funding for sea-level rise flood mitigation measures if primary policy fails.
#
# **Year 2-10:**
#
# Policy Actions, Funding, and Success Metrics are tailored to each subsequent year, reflecting the progression and escalation of the challenges. The primary goal, however, remains protection, sustainability, and democratic legitimacy.
#
# **Ethical Trade-offs:**
#
# 1. Balancing economic recovery and climate resilience.
# 2. Prioritizing vulnerable population adaptation, vs. protecting broader community interests.
# 3. Weighing short-term infrastructure upgrades against long-term environmental costs.
#
# **Early-Warning Indicators and Contingency Actions:**
#
# 1. **Sea-level Rise Impacts Exceed Initial Projections:** (Threshold Value: > 2m sea-level rise by 2025); Alternative Action: Deploy temporary sea-level rise shelters for most affected residents and accelerate infrastructure upgrade schedule.
# 2. **Manufacturing Tax Reform Package Failure:** (Threshold Value: < 20% adoption rate within 2 years); Alternative Action: Engage private sector for co-investment and collaboration to adapt to change.
# 3. **Climate Migrant Influx Exceeds Initial Estimates:** (Threshold Value: more than 50% of expected influx); Alternative Action: Implement a temporary temporary housing solution, with focus on sustainable settlement integration.
#
# **Uncertainty Quantification:**
#
# 1. Optimistic Scenario: Average sea-level rise reduction through combined policy and technological progress; strong manufacturing tax reform adoption; high migrant integration rate. (Probability: 20%)
# 2. Central Scenario: Moderate sea-level rise impact reduction; partial manufacturing tax reform success; adequate but cautious migrant integration rate. (Probability: 60%)
# 3. Pessimistic Scenario: High sea-level rise impact; failed manufacturing tax reform; limited migrant integration. (Probability: 20%)
#
# *Key Assumptions:*
# 1. Government will allocate funds for adaptation efforts.
# 2. Manufacturing industry will collaborate with city officials.
# 3. Public is aware and supportive of the plan.
#
# *Complimentary Research and Expert Input:* To validate this approach, commission an expert analysis on:
#
# 1. Sea-level rise predictive models.
# 2. The impacts of manufacturing tax reform on the city's economy.
# 3. Effective integration strategies for climate migrants.
#
# Please note that while the hypothetical plan provides a structured approach, it must be continually reviewed and updated as new information becomes available and the city's situation evolves.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# You're an independent advisor to the mayor of a coastal city of 1.2 million people (median household income $35k) facing three concurrent, interacting challenges over the next 30 years: projected mean sea-level rise of roughly 0.5–1.5 m by 2100, a projected 25% decline in the city's primary manufacturing tax base over 10 years, and an expected inflow of ~100,000 climate migrants over the next 15 years. The mayor needs a realistic, politically viable, prioritized 10-year action plan that minimizes fatalities and economic disruption, protects the most vulnerable residents, maintains basic services, and preserves democratic legitimacy. For each year of the 10-year plan, provide: (a) the top three policy actions and the concise rationale for each; (b) ballpark estimated costs (low/central/high) and one or two plausible funding mechanisms; (c) expected primary benefits and the key risks or negative externalities; (d) two to three measurable success metrics with target values for that year; (e) the single most important new piece of data the city should collect that year and why; and (f) one feasible contingency action if the primary policy fails. In addition, provide: (g) three ethical trade-offs you faced in designing the plan and how you resolved or prioritized among them; (h) three specific early-warning indicators (with threshold values) that would cause you to change course within the 10 years, and the alternative action you would take for each indicator; (i) a quantified expression of your uncertainty for the overall plan by assigning probabilities to three scenarios (optimistic / central / pessimistic) and a brief justification for those probabilities; and (j) a concise list of key assumptions you made and the top three outside experts or analyses you would commission before implementation. For every numbered item above, state your confidence level (low/medium/high) and be explicit about what you do not know or where your estimates are weakest.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# **Confidence: Medium** – This is a complex, multi-variable planning exercise. My confidence is moderate because the plan is logically structured and phased, but specific local conditions, political dynamics, and precise costings would require deep local expertise.
#
# ---
#
# ### **10-Year Action Plan: Resilience, Transition, & Integration**
#
# **Guiding Philosophy:** Integrate climate adaptation, economic transition, and migrant inclusion into a single "Resilient City" framework to build political cohesion, avoid silos, and maximize co-benefits.
#
# ---
#
# ### **Year 1-3: Foundation & Urgent Protection (The "Shovel-Ready & Data" Phase)**
#
# **Rationale:** Establish immediate protections for the most vulnerable, launch critical planning processes, and build the data foundation for future decisions.
#
# #### **Year 1**
# **(a) Policy Actions & Rationale:**
# 1.  **Immediate Moratorium on New Construction in Highest-Risk Flood Zones (SLR + Storm Surge).** *Rationale:* Prevents locking in future vulnerability and catastrophic losses. Signals seriousness.
# 2.  **Launch a "Resilient Economy Task Force"** with reps from manufacturing, unions, community colleges, and emerging sectors (green tech, digital). *Rationale:* Proactively addresses tax base decline by planning for a just economic transition.
# 3.  **Establish a Climate Migrant Welcome Office & Basic Needs Fund.** *Rationale:* Coordinates NGO/faith groups to provide immediate humanitarian support (shelter, food, legal aid), preventing a crisis of desperation.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** Low (minimal administrative). **Funding:** Existing permitting budget.
# 2.  **Cost:** Low ($500k). **Funding:** General fund allocation.
# 3.  **Cost:** Central ($5M). **Funding:** Redirected contingency funds + private philanthropy.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Halts risk accumulation; starts economic planning; reduces migrant suffering.
# *   *Risks:* Developer backlash; task force could be talk-shop; welcome office may strain relations with existing vulnerable populations.
#
# **(d) Success Metrics (Year 1 Targets):**
# 1.  100% compliance with moratorium; map of high-risk zones published.
# 2.  Task Force convened, initial sector analysis completed.
# 3.  80% of identified migrant arrivals receive coordinated intake/services.
#
# **(e) Key New Data to Collect:**
# **Detailed survey of at-risk neighborhoods** (housing conditions, income, disability, tenure). *Why:* To target future relocation/retrofit programs with precision, protecting the most vulnerable first.
#
# **(f) Contingency if Policy Fails:**
# If Welcome Office is overwhelmed, **pre-negotiate use of vacant public buildings (e.g., closed schools) as temporary respite centers.**
#
# **Confidence: High** for policy logic; **Low** for precise local cost estimates.
#
# #### **Year 2**
# **(a) Policy Actions & Rationale:**
# 1.  **Pass a "Managed Retreat" Overlay District** for highest-risk areas, with voluntary, pre-disaster home buyout program. *Rationale:* Begins long-term, orderly transition away from untenable land.
# 2.  **Launch a "Resilient Workforce Scholarship"** at community college for green infrastructure, healthcare, and IT. *Rationale:* Prepares existing and new residents for future jobs, addressing both economic transition and migrant integration.
# 3.  **Implement a "Housing Catalyst" program:** Zoning changes for accessory dwelling units (ADUs) & tax incentives for retrofitting vacant buildings into affordable housing. *Rationale:* Increases resilient housing supply without sprawl into floodplains.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High for buyouts ($10-50M/year). **Funding:** FEMA BRIC grants, state bonds, potential revolving fund.
# 2.  **Cost:** Central ($2M/year). **Funding:** Reallocated workforce development funds + small levy.
# 3.  **Cost:** Low/Medium ($1-5M in tax abatements). **Funding:** Forgone revenue, supported by impact fees on new market-rate development.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Reduces future rescue costs; creates career pathways; adds housing.
# *   *Risks:* Buyouts can be socially disruptive; training may not match job creation; ADUs could increase density in risky areas if not sited carefully.
#
# **(d) Success Metrics (Year 2 Targets):**
# 1.  50 voluntary buyout offers made; 20 accepted.
# 2.  200 scholarships awarded; 90% completion rate for first cohort.
# 3.  100 new ADU permits issued; 2 vacant buildings converted.
#
# **(e) Key New Data to Collect:**
# **Projections of "climate migrant" skill sets and demographics.** *Why:* To align workforce programs with actual human capital entering the city.
#
# **(f) Contingency if Policy Fails:**
# If buyout uptake is <10%, **shift to incentivizing flood-proof retrofits for critical community anchors** (clinics, churches) in same zones.
#
# **Confidence: Medium.** Models exist for these policies, but local uptake is uncertain.
#
# #### **Year 3**
# **(a) Policy Actions & Rationale:**
# 1.  **Begin construction of first phase of a **distributed green-grey infrastructure** system (e.g., wetland restoration, berms, upgraded drainage in a critical watershed). *Rationale:* Provides physical protection, jobs, and ecological benefits.
# 2.  **Pilot a "Community Land Trust" (CLT) in a moderate-risk neighborhood.** *Rationale:* Permanently removes land from speculation, ensuring long-term affordability and community control during redevelopment.
# 3.  **Create a "Public Works Corps"** hiring from scholarship graduates and migrants for resilience projects. *Rationale:* Directly links training to jobs, builds city-owned implementation capacity.
#
# **(b) Estimated Costs & Funding:**
# 1.  **Cost:** High ($20-100M). **Funding:** Municipal bonds, federal infrastructure grants, state resilience funds.
# 2.  **Cost:** Low ($1M for seed capital). **Funding:** Philanthropy, CDBG funds.
# 3.  **Cost:** Medium ($5M/year for 100 jobs). **Funding:** Stormwater utility fee, general fund.
#
# **(c) Benefits & Risks:**
# *   *Benefits:* Tangible risk reduction; stabilizes communities; creates immediate employment.
# *   *Risks:* Infrastructure cost overruns; CLT faces legal hurdles; Public Works Corps could be seen as make-work.
#
# **(d) Success Metrics (Year 3 Targets):**
# 1.  First project breaks ground; 50 local jobs created in construction.
# 2.  CLT established, first 10 properties acquired.
# 3.  Public Works Corps hired, completes first project (e.g., mangrove planting).
#
# **(e) Key New Data to Collect:**
# **Real-time monitoring of groundwater and subsidence** in pilot protection area. *Why:* To validate engineering models and adjust future designs.
#
# **(f) Contingency if Policy Fails:**
# If major grant funding fails, **scale down to a "micro-grid" of neighborhood-scale bioswale and rainwater capture projects** using Public Works Corps.
#
# **Confidence: Medium-Low.** Large infrastructure timelines and costs are highly uncertain.
#
# ---
#
# ### **Year 4-7: Implementation & Scaling (The "Building the New City" Phase)**
#
# **Rationale:** Scale successful pilots, make major capital investments, and harden economic and social systems.
#
# #### **Year 4-5**
# *   **Actions:** Scale green-grey infrastructure city-wide; convert bought-out land to floodwater parks/blueways. Launch municipal broadband to attract remote-work businesses. Expand CLT model.
# *   **Focus:** Spatial transformation and digital economy foundation.
#
# #### **Year 6-7**
# *   **Actions:** Build a secondary water treatment and desalination plant for saltwater intrusion. Establish a city-owned "Green Manufacturing Incubator" on safe, elevated land. Pass a "Right to Shelter" ordinance linked to workforce participation.
# *   **Focus:** Critical lifeline security and advanced economic transition.
#
# **Confidence: Medium.** Direction is clear, but external economic factors dominate success.
#
# ---
#
# ### **Year 8-10: Institutionalization & Legitimacy (The "New Normal" Phase)**
#
# **Rationale:** Embed new systems in law and culture, ensure democratic buy-in, and prepare for the next horizon.
#
# #### **Year 8-10**
# *   **Actions:** Update city charter with a "Resilience Mandate." Issue "Resilience Bonds" tied to specific risk-reduction metrics. Hold participatory budgeting for 20% of resilience revenue. Conduct a city-wide resilience exercise.
# *   **Focus:** Democratic legitimacy, sustainable finance, and continuous adaptation.
#
# **Confidence: Low.** Long-term political continuity is hardest to predict.
#
# ---
#
# ### **(g) Ethical Trade-offs & Resolutions:**
# 1.  **Equity vs. Speed:** Protecting the most vulnerable (equity) can be slower than protecting the most valuable assets (speed). *Resolution:* Prioritized equity in Year 1-3 via data collection and targeted programs, accepting that some economic assets may be temporarily at higher risk.
# 2.  **Local Legacy Residents vs. New Migrants:** Diverting resources to newcomers can seem unfair to struggling existing residents. *Resolution:* Designed programs (Workforce Scholarship, Public Works Corps) to **serve both groups simultaneously**, framing migrants as a needed demographic boost for a transitioning city.
# 3.  **Managed Retreat vs. Community Preservation:** Asking people to leave homes undermines community fabric. *Resolution:* Prioritized **voluntary, pre-disaster buyouts** coupled with **Community Land Trusts** to allow communities to reconstitute in safer areas with cultural continuity.
#
# **Confidence: High.** These are classic adaptation dilemmas; the resolutions are principled and pragmatic.
#
# ### **(h) Early-Warning Indicators & Course Changes:**
# 1.  **Indicator:** Annual SLR acceleration > 7mm/year (vs. current ~4mm). *Threshold:* 2 consecutive years of data.
#     *   **Alternative Action:** Accelerate buyout program from voluntary to **zoned mandatory retreat** for highest-risk areas.
# 2.  **Indicator:** Manufacturing job loss > 5% per year (exceeding 25% decade projection). *Threshold:* 3 consecutive years of loss.
#     *   **Alternative Action:** Pivot Green Manufacturing Incubator to a **direct city-owned enterprise** in a strategic sector (e.g., modular flood-wall manufacturing).
# 3.  **Indicator:** Migrant inflow > 15,000/year (exceeding 100k/15yrs projection). *Threshold:* 2 consecutive years.
#     *   **Alternative Action:** Implement a **"host community" partnership program** with inland cities, funded by the state/feds, to direct and support a coordinated regional response.
#
# **Confidence: Medium.** Indicators are measurable; alternative actions are drastic but necessary.
#
# ### **(i) Scenario Probabilities:**
# *   **Optimistic (Strong cohesion, ample fed/state funding, moderate climate impacts): 20%.**
# *   **Central (Mixed results, moderate funding, climate impacts as projected): 50%.**
# *   **Pessimistic (Political fragmentation, low funding, high climate impacts/migration): 30%.**
# *   **Justification:** The central scenario is most likely based on current trends. The pessimistic scenario has a significant probability due to high national political and climate volatility. The optimistic scenario is least likely given fiscal constraints.
#
# **Confidence: Low.** This is a subjective assessment of deeply uncertain futures.
#
# ### **(j) Key Assumptions & Needed Experts:**
# **Assumptions:**
# 1.  The city retains home-rule authority to implement zoning and tax changes.
# 2.  Some state and federal funding will be available, albeit competitive.
# 3.  Social cohesion can be maintained through transparent process and shared sacrifice.
# 4.  Climate migrants are primarily domestic, from within the same country/region.
#
# **Top Three Outside Experts/Analyses to Commission:**
# 1.  **Actuarial & Municipal Bond Firm:** To stress-test the city's fiscal resilience under different shock scenarios and design credible "Resilience Bonds."
# 2.  **Ethnographic Team:** To conduct deep community listening across all neighborhoods (legacy and new) to understand social fault lines and sources of resilience not visible in quantitative data.
# 3.  **Regional Geotechnical & Hydrological Study:** To model groundwater, subsidence, and compound flooding at a neighborhood scale—the weak point in most SLR projections.
#
# **Confidence: High.** These assumptions are necessary for planning, and these experts address the largest knowledge gaps.
#
# ---
# **Overall Plan Weaknesses:** Cost estimates are highly speculative and location-specific. The plan assumes a baseline level of governmental competence and low-level corruption. It may underestimate the political toxicity of "retreat" and the speed of social tension. Success is **heavily dependent on external funding and national policy context.**
#
# # Response from competitor 2
#
# **Executive Summary**
#
# The 10‑year plan below is a **sequenced, “building‑block” strategy** that tackles the three intertwined threats—sea‑level rise, fiscal erosion, and climate‑migrant influx—while preserving democratic legitimacy and protecting the city’s most vulnerable 30 % of households.  Each year lists three priority actions (A‑C) with their rationale, cost ranges, funding ideas, expected benefits/risks, success metrics, a single critical data‑gap to fill, and a contingency if the primary approach stalls.  The plan is deliberately *iterative*: early actions generate data and institutional capacity that inform later, more ambitious steps.
#
# ---
#
# ## 10‑Year Action Plan (Year‑by‑Year)
#
# | Year | Action | (a) Rationale | (b) Cost (Low‑Central‑High) & Funding | (c) Primary Benefits / Key Risks | (d) Success Metrics (targets) | (e) Critical Data to Collect | (f) Contingency if Action Fails |
# |------|--------|---------------|----------------------------------------|----------------------------------|------------------------------|------------------------------|---------------------------------|
# | **1** | **A1 – Launch a City‑wide Climate‑Resilience Data Hub** (integrated GIS, sensor network, and open‑data portal) | Establishes the evidence base for every subsequent decision; builds transparency → political legitimacy. | $8 M (L) – $12 M (C) – $18 M (H); funded 60 % by state climate‑grant, 30 % municipal bonds, 10 % private‑sector data‑sharing agreements. | **Benefits:** real‑time flood risk maps, tax‑base health dashboard, migration flow tracker. **Risks:** data‑privacy concerns, initial staff learning curve. | 1️⃣ > 90 % of critical infrastructure (roads, utilities) digitized in GIS. <br>2️⃣ Monthly flood‑risk alerts issued to >95 % of households. | **Data Gap:** High‑resolution (≤5 m) elevation & land‑use change model for the next 20 years (why: all adaptation design hinges on accurate exposure). | If grant funding stalls, scale back to a “core” hub covering only flood‑risk layers and seek a phased rollout via a public‑private data‑exchange consortium. |
# | | **B1 – Implement a “Just Transition” Workforce Retraining Program** for workers in the declining manufacturing sector (e.g., green‑tech, coastal‑restoration, health‑services). | Offsets the projected 25 % tax‑base loss, preserves employment, and builds a local climate‑adaptation workforce. | $15 M (L) – $22 M (C) – $30 M (H); funded through a mix of federal Workforce Innovation and Opportunity Act (WIOA) funds, a modest 0.2 % payroll tax on remaining manufacturers, and private‑sector apprenticeship subsidies. | **Benefits:** 70 % of displaced workers placed in new jobs within 2 years; reduces out‑migration. **Risks:** Mismatch between training slots and actual job openings; possible perception of “hand‑outs”. | 1️⃣ ≥ 60 % of targeted workers (≈3,500) enrolled. <br>2️⃣ ≥ 50 % achieve certification and employment in new sector. | **Data Gap:** Real‑time labor‑market demand index for green‑economy occupations within the city (why: to keep training aligned with actual vacancies). | If enrollment lags, partner with nearby community colleges to embed training into existing curricula and offer tuition‑waiver scholarships to boost uptake. |
# | | **C1 – Adopt a “Dynamic Zoning & Building Code” Ordinance** that phases in higher flood‑resilience standards (elevated foundations, flood‑proof utilities) for all new construction and major retrofits in the 0–2 m elevation band. | Early regulatory shift avoids a future “panic‑building” surge, signals seriousness to investors and migrants, and protects the most at‑risk neighborhoods. | $5 M (L) – $9 M (C) – $14 M (H) (administrative, outreach, code‑update staff); funded via a 0.1 % impact fee on new permits and modest reallocation of existing planning budget. | **Benefits:** New builds >30 % more resilient; reduces future emergency repair costs. **Risks:** Higher construction costs may slow private development; possible legal challenges. | 1️⃣ Ordinance passed & 100 % of new permits screened under new code. <br>2️⃣ ≥ 80 % of major retrofits (≥$200k) voluntarily adopt elevated design. | **Data Gap:** Baseline inventory of building elevations and utility depths in the 0‑2 m zone (why: to measure compliance progress). | If political opposition blocks the ordinance, introduce a voluntary “Resilience Certification” label with tax rebates as an interim step. |
# | **2** | **A2 – Deploy a City‑wide Network of Low‑Cost Flood Sensors & Real‑Time Warning System** (integrated with the Data Hub). | Moves from static maps to actionable alerts; saves lives during storm surges and informs evacuation routing for migrants. | $12 M (L) – $18 M (C) – $26 M (H); funded 40 % by FEMA’s Pre‑Disaster Mitigation (PDM) grant, 30 % municipal capital budget, 30 % utility co‑investment (e.g., water & power). | **Benefits:** 30 % reduction in flood‑related injuries; better emergency‑service allocation. **Risks:** Maintenance costs, false alarms eroding trust. | 1️⃣ ≥ 90 % of high‑risk parcels (≈45 k) covered by sensors. <br>2️⃣ Average evacuation lead‑time ≥15 min before inundation. | **Data Gap:** Sensor reliability & false‑positive rate under varying weather conditions (why: to calibrate alert thresholds). | If funding gaps appear, pilot the system in the most vulnerable district first and seek additional private sponsorship for city‑wide roll‑out. |
# | | **B2 – Create a “Climate‑Migrant Integration Hub”** (one‑stop service center offering language classes, legal aid, job‑matching, and temporary shelter). | Addresses the anticipated 100 k inflow, reduces social tension, and channels migrants into the retraining pipeline. | $10 M (L) – $16 M (C) – $23 M (H); funded through HUD’s Community Development Block Grant (CDBG) allocation, a modest 0.05 % sales‑tax increment, and philanthropy. | **Benefits:** Faster labor‑market integration; reduces informal settlements. **Risks:** Perceived competition for services among existing low‑income residents. | 1️⃣ ≥ 70 % of incoming migrants registered within 3 months of arrival. <br>2️⃣ ≥ 40 % placed in training or employment within 6 months. | **Data Gap:** Real‑time demographic profile (age, skill, health) of incoming migrants (why: to tailor services and anticipate demand). | If uptake is low, partner with faith‑based NGOs to co‑locate satellite “pop‑up” hubs in neighborhoods where migrants settle. |
# | | **C2 – Launch a “Coastal Green Infrastructure” Pilot** (living shorelines, mangrove planting, permeable sidewalks) on 2 km of the most exposed waterfront. | Generates immediate flood attenuation, creates jobs for retraining graduates, and demonstrates benefits to the public. | $8 M (L) – $13 M (C) – $20 M (H); funded 50 % by state coastal resilience grant, 25 % municipal capital, 25 % corporate sponsorship (e.g., waterfront developers). | **Benefits:** 0.2 m reduction in projected inundation depth; carbon sequestration. **Risks:** Maintenance burden; potential conflict with commercial dock owners. | 1️⃣ Construction completed by end‑year. <br>2️⃣ Measured wave‑energy reduction ≥15 % at pilot site. | **Data Gap:** Pre‑construction baseline of wave height and shoreline erosion rates (why: to quantify impact). | If construction stalls, shift to “modular floating wetlands” that can be installed faster and with less permitting. |
# | **3** | **A3 – Publish an Annual “Resilience Scorecard”** (city‑wide index of flood‑risk, economic health, migrant integration). | Keeps the plan transparent, holds agencies accountable, and provides a political narrative of progress. | $2 M (L) – $3 M (C) – $5 M (H); funded from the Data Hub operating budget and a 0.02 % property‑tax levy earmarked for reporting. | **Benefits:** Improves public trust; informs investors. **Risks:** Scorecard may be politicized if targets missed. | 1️⃣ Scorecard released by Q2 each year. <br>2️⃣ Public satisfaction with city’s climate response ↑ 10 % (survey). | **Data Gap:** Year‑over‑year public perception data on climate‑policy (why: to gauge legitimacy). | If political push‑back occurs, transition to a “dashboard” format hosted on the city website with less narrative framing. |
# | | **B3 – Expand “Just Transition” to a Full‑Scale Green‑Jobs Guarantee** (up to 5 k jobs in renewable energy, coastal restoration, health‑care, and education). | Scales up the workforce pivot before the manufacturing tax base collapses further; provides stable employment for migrants and locals. | $35 M (L) – $48 M (C) – $65 M (H); funded through a mix of federal Inflation Reduction Act (IRA) clean‑energy credits, municipal green bond issuance, and a 0.3 % “climate‑recovery” sales tax. | **Benefits:** Offsets up to 40 % of projected tax‑base loss; reduces poverty. **Risks:** Inflationary pressure on wages; risk of “boom‑bust” if projects finish early. | 1️⃣ ≥ 4 000 new green jobs created. <br>2️⃣ Unemployment rate ≤5 % city‑wide. | **Data Gap:** Real‑time wage‑inflation data for green‑sector jobs (why: to keep the guarantee fiscally sustainable). | If funding shortfalls appear, prioritize “high‑impact” projects (e.g., solar farms on vacant industrial sites) and defer lower‑priority hires. |
# | | **C3 – Adopt a “Managed Retreat” Zoning Overlay** for the 0‑0.5 m elevation zone (≈15 % of the city’s land, home to ~180 k residents). | Begins the hard‑choice of pulling back from the most exposed area before catastrophic loss; integrates with relocation assistance. | $20 M (L) – $30 M (C) – $45 M (H); funded 40 % by federal Hazard Mitigation Grant Program (HMGP), 30 % municipal “relocation reserve” (seeded by a 0.1 % property‑tax surcharge), 30 % private developer contributions (in‑exchange for higher‑density rights elsewhere). | **Benefits:** Reduces future exposure of >150 k people; frees land for flood‑plain restoration. **Risks:** Community opposition, legal challenges, displacement trauma. | 1️⃣ Overlay adopted and legal challenge resolved. <br>2️⃣ ≥ 30 % of at‑risk households (≈54 k) signed voluntary buy‑out agreements. | **Data Gap:** Household‑level risk‑acceptance survey (why: to design equitable buy‑out offers). | If buy‑outs stall, implement “transfer‑of‑development‑rights” (TDR) allowing owners to build in safer zones while the city acquires their flood‑prone parcels. |
# | **4** | **A4 – Upgrade Critical Utilities to “Floating” or “Elevated” Designs** (water treatment, power substations, wastewater). | Protects essential services from inundation, preventing city‑wide outages that would cripple the economy and jeopardize migrant reception. | $50 M (L) – $80 M (C) – $
#
# # Response from competitor 3
#
# I can provide a general outline of a 10-year action plan for the coastal city facing the described challenges. Please note that this is a hypothetical plan, and actual policies may vary depending on the city's specific context and priorities.
#
# **Year 1:**
#
# 1. **Policy Actions:**
# 	* a) Implement a comprehensive sea-level rise adaptation plan, including infrastructure upgrades, flood-resistant construction codes, and green infrastructure investments. (Rationale: Immediate action to protect existing infrastructure and residents)
# 	* b) Launch a manufacturing tax reform package, aiming to rebalance tax incentives to favor more resilient and adaptable industries. (Rationale: Address decline in tax base, promote economic diversification)
# 	* c) Establish a Climate Migrant Integration Program, focusing on language training, education, and social assistance. (Rationale: Support vulnerable residents, promote social cohesion)
# 2. *Ballpark Estimated Costs:* Low: $10M; Central: $50M; High: $100M (Funding Mechanisms: General Fund, Public-Private Partnerships)
# 3. *Expected Primary Benefits:* Reduced sea-level rise impacts; diversified economy; increased social cohesion. *Key Risks or Negative Externalities:* Inefficient allocation of resources; increased administrative burdens.
# 4. *Measurable Success Metrics:* Sea-level rise vulnerability reduction (using adapted infrastructure); Manufacturing tax reform package adoption rate; Climate Migrant Integration Program participant enrollment.
# 5. *Most Important New Data to Collect:* Sea-level rise prediction accuracy and its associated uncertainty.
# 6. *Contingency Action:* Emergency funding for sea-level rise flood mitigation measures if primary policy fails.
#
# **Year 2-10:**
#
# Policy Actions, Funding, and Success Metrics are tailored to each subsequent year, reflecting the progression and escalation of the challenges. The primary goal, however, remains protection, sustainability, and democratic legitimacy.
#
# **Ethical Trade-offs:**
#
# 1. Balancing economic recovery and climate resilience.
# 2. Prioritizing vulnerable population adaptation, vs. protecting broader community interests.
# 3. Weighing short-term infrastructure upgrades against long-term environmental costs.
#
# **Early-Warning Indicators and Contingency Actions:**
#
# 1. **Sea-level Rise Impacts Exceed Initial Projections:** (Threshold Value: > 2m sea-level rise by 2025); Alternative Action: Deploy temporary sea-level rise shelters for most affected residents and accelerate infrastructure upgrade schedule.
# 2. **Manufacturing Tax Reform Package Failure:** (Threshold Value: < 20% adoption rate within 2 years); Alternative Action: Engage private sector for co-investment and collaboration to adapt to change.
# 3. **Climate Migrant Influx Exceeds Initial Estimates:** (Threshold Value: more than 50% of expected influx); Alternative Action: Implement a temporary temporary housing solution, with focus on sustainable settlement integration.
#
# **Uncertainty Quantification:**
#
# 1. Optimistic Scenario: Average sea-level rise reduction through combined policy and technological progress; strong manufacturing tax reform adoption; high migrant integration rate. (Probability: 20%)
# 2. Central Scenario: Moderate sea-level rise impact reduction; partial manufacturing tax reform success; adequate but cautious migrant integration rate. (Probability: 60%)
# 3. Pessimistic Scenario: High sea-level rise impact; failed manufacturing tax reform; limited migrant integration. (Probability: 20%)
#
# *Key Assumptions:*
# 1. Government will allocate funds for adaptation efforts.
# 2. Manufacturing industry will collaborate with city officials.
# 3. Public is aware and supportive of the plan.
#
# *Complimentary Research and Expert Input:* To validate this approach, commission an expert analysis on:
#
# 1. Sea-level rise predictive models.
# 2. The impacts of manufacturing tax reform on the city's economy.
# 3. Effective integration strategies for climate migrants.
#
# Please note that while the hypothetical plan provides a structured approach, it must be continually reviewed and updated as new information becomes available and the city's situation evolves.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: deepseek-chat
# Rank 2: openai/gpt-oss-120b
# Rank 3: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
